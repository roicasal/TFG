# %%
import ROOT
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ROOT.EnableImplicitMT(10)

# %% [markdown]
# Neste ficheiro vaise realizar un fit ao montecarlo para entender o comportamento do pico de masa dos samples tag e match das trazas VM de OO, de forma que os resultados obtidos serán usados despois nos datos como parámetros iniciais do fit ou incluso algúns como parámetros fixados

# %% [markdown]
# Comezamos entón por ler os datos de MC

# %%
pathmc = '/rxc_lustre/ivan.cambon/TrackCalibmu_AA_tuples/MC/OO_2025/trackeffmu_OO_mc_2025.root'


tdf_mc = ROOT.RDataFrame("charmonium_mu_mu_VM_mup_Tag/DecayTree", pathmc)

# %% [markdown]
# Aplicamos os mesmos filtros que en data:

# %%
datamc = tdf_mc.Filter("dimuon_BPVIP < 0.35 && dimuon_DOCA_12 < 0.5 &&  dimuon_PT > 2000 && mum_CHI2DOF < 1.5 && mum_P > 1000 && mum_PID_MU > 0 && mum_PT > 1500 && mup_CHI2DOF < 1.2")
datamc = datamc.Filter("abs(dimuon_TRUEID)==443")

# %% [markdown]
# Definimos a variable sobre a que facer os fits (masa) e a continuación realízase o fit a unha Gaussiana + CB

# %%
mass = ROOT.RooRealVar("dimuon_M", "m(#mu^{+}#mu^{-})", 2600, 3600) 
data = datamc.AsNumpy(["dimuon_M"])
roo_data = ROOT.RooDataSet.from_numpy(
    {"dimuon_M": data["dimuon_M"]},
    [mass]
)

# %%
# 1. Variables do sinal
mean   = ROOT.RooRealVar("mean", "mean", 3096, 3070, 3130)
sigma1 = ROOT.RooRealVar("sigma1", "sigma gauss", 20, 2, 80)  # O núcleo estreito
sigma2 = ROOT.RooRealVar("sigma2", "sigma cb", 45, 15, 80)   # As colas
alpha  = ROOT.RooRealVar("alpha", "alpha", 1.5, 0.1, 10)
n      = ROOT.RooRealVar("n", "n", 3, -5, 150)               # Protexemos n para que non colapse

# 2. Funcións do sinal
gauss = ROOT.RooGaussian("gauss", "Gaussian Core", mass, mean, sigma1)
cb    = ROOT.RooCBShape("cb", "Crystal Ball Tail", mass, mean, sigma2, alpha, n)

sig_frac = ROOT.RooRealVar("sig_frac", "fraction Gauss/CB", 0.5, 0, 1)

# Creamos o pdf do sinal combinado
signal = ROOT.RooAddPdf("signal", "Gauss + CB", [gauss, cb], [sig_frac])

#Fiteamos
signal.fitTo(roo_data)
# Out:
# <cppyy.gbl.RooFitResult object at 0x(nil)>
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (gauss,cb)
#  **********
#  **   10 **SET PRINT           1
#  **********
#  **********
#  **   11 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha        1.50000e+00  7.00000e-01    1.00000e-01  1.00000e+01
#      2 mean         3.09600e+03  6.00000e+00    3.07000e+03  3.13000e+03
#      3 n            3.00000e+00  4.00000e+00   -5.00000e+00  1.50000e+02
#      4 sig_frac     5.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      5 sigma1       2.00000e+01  7.80000e+00    2.00000e+00  8.00000e+01
#      6 sigma2       4.50000e+01  6.50000e+00    1.50000e+01  8.00000e+01
#  **********
#  **   12 **SET ERR         0.5
#  **********
#  **********
#  **   13 **SET PRINT           1
#  **********
#  **********
#  **   14 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   15 **MIGRAD        3000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=74284.7 FROM MIGRAD    STATUS=INITIATE       28 CALLS          29 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        1.50000e+00   7.00000e-01   2.09487e-01   1.64455e+01
#    2  mean         3.09600e+03   6.00000e+00   2.03277e-01  -1.93199e+03
#    3  n            3.00000e+00   4.00000e+00   1.20622e-01   8.95279e+02
#    4  sig_frac     5.00000e-01   1.00000e-01   2.01358e-01   2.23778e+03
#    5  sigma1       2.00000e+01   7.80000e+00   2.42752e-01  -3.47455e+03
#    6  sigma2       4.50000e+01   6.50000e+00   2.01990e-01  -2.34183e+03
#                                ERR DEF= 0.5
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (74452.6) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=0.551678	mean=3101.95	n=145.628	sig_frac=0.893968	sigma1=39.4592	sigma2=77.4552
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.69, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3050.37, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3055.17, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3038.47, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3040.91, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.77, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2962.31, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2860.85, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3038.99, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.79, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2964.5, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3011.75, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#     ... (remaining 2038 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0097045/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00806864/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00878441/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0101067/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 8.4249e-18/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00779428/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00830089/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00995367/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0100901/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00807705/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00861076/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00757128/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 0.551678,mean = 3101.95,n = 145.628,sig_frac = 0.893968,sigma1 = 39.4592,sigma2 = 77.4552)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3135.79), !jacList=(), !facList=(), !func=cb=0.908993/254.347, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (74452.6) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=0.551678	mean=3101.95	n=145.628	sig_frac=0.893968	sigma1=39.4592	sigma2=77.4552
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.69, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3050.37, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3055.17, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3038.47, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3040.91, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.77, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2962.31, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2860.85, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3038.99, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.79, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2964.5, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3011.75, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#     ... (remaining 2038 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0097045/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00806864/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00878441/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0101067/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 8.4249e-18/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00779428/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00830089/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00995367/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0100901/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00807705/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00861076/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00757128/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 0.551678,mean = 3101.95,n = 145.628,sig_frac = 0.893968,sigma1 = 39.4592,sigma2 = 77.4552)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3135.79), !jacList=(), !facList=(), !func=cb=0.908993/254.364, !sumCat=()
#
#  MIGRAD FAILS TO FIND IMPROVEMENT
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (74452.6) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=0.551678	mean=3101.95	n=145.628	sig_frac=0.893968	sigma1=39.4592	sigma2=77.4552
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.69, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3050.37, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3055.17, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3038.47, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3040.91, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.77, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2962.31, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2860.85, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3038.99, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.79, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2964.5, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3011.75, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#     ... (remaining 2038 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0097045/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00806864/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00878441/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0101067/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 8.4249e-18/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00779428/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00830089/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00995367/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0100901/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00807705/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00861076/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00757128/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 0.551678,mean = 3101.95,n = 145.628,sig_frac = 0.893968,sigma1 = 39.4592,sigma2 = 77.4552)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3135.79), !jacList=(), !facList=(), !func=cb=0.908993/254.347, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (74452.6) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=0.556199	mean=3101.95	n=145.628	sig_frac=0.893968	sigma1=39.4592	sigma2=77.4552
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3047.48, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.556199, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3049.6, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.556199, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3036.06, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.556199, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3002.51, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.556199, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2845.66, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.556199, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2986.26, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.556199, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3048.03, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.556199, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2794.21, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.556199, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.57, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.556199, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3045.06, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.556199, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3037.62, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.556199, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2881.4, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.556199, n=n=145.628
#     ... (remaining 2038 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0097045/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00806864/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00878441/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0101067/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 8.4249e-18/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00779428/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00830089/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00995367/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0100901/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00807705/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00861076/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00757128/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 0.556199,mean = 3101.95,n = 145.628,sig_frac = 0.893968,sigma1 = 39.4592,sigma2 = 77.4552)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3135.79), !jacList=(), !facList=(), !func=cb=0.908993/253.528, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (74452.6) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=0.551678	mean=3102.02	n=145.628	sig_frac=0.893968	sigma1=39.4592	sigma2=77.4552
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.77, m0=mean=3102.02, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2962.31, m0=mean=3102.02, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2860.85, m0=mean=3102.02, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3038.99, m0=mean=3102.02, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3059.24, m0=mean=3102.02, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.79, m0=mean=3102.02, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2964.5, m0=mean=3102.02, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3011.75, m0=mean=3102.02, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3045.14, m0=mean=3102.02, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2982.22, m0=mean=3102.02, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3032.15, m0=mean=3102.02, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3026.42, m0=mean=3102.02, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#     ... (remaining 2038 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0096996/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00805909/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0087926/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0101062/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 8.30215e-18/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00778437/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00831006/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00995056/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.010089/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00806751/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00860216/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00756114/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 0.551678,mean = 3102.02,n = 145.628,sig_frac = 0.893968,sigma1 = 39.4592,sigma2 = 77.4552)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3135.79), !jacList=(), !facList=(), !func=cb=0.909349/-nan, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (74452.6) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=0.551678	mean=3101.95	n=145.628	sig_frac=0.894841	sigma1=39.4592	sigma2=77.4552
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.69, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3050.37, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3055.17, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3038.47, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3040.91, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.77, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2962.31, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2860.85, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3038.99, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.79, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2964.5, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3011.75, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#     ... (remaining 2038 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0097045/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.894841)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00806864/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.894841)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00878441/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.894841)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0101067/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.894841)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 8.4249e-18/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.894841)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00779428/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.894841)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00830089/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.894841)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00995367/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.894841)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0100901/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.894841)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00807705/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.894841)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00861076/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.894841)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00757128/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.894841)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 0.551678,mean = 3101.95,n = 145.628,sig_frac = 0.894841,sigma1 = 39.4592,sigma2 = 77.4552)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3135.79), !jacList=(), !facList=(), !func=cb=0.908993/254.352, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (74452.6) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=0.551678	mean=3101.95	n=145.628	sig_frac=0.893968	sigma1=39.5155	sigma2=77.4552
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.69, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3050.37, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3055.17, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3038.47, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3040.91, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.77, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2962.31, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2860.85, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3038.99, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.79, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2964.5, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3011.75, m0=mean=3101.95, sigma=sigma2=77.4552, alpha=alpha=0.551678, n=n=145.628
#     ... (remaining 2038 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00969181/99.0507,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00806233/99.0507,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00877541/99.0507,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0100923/99.0507,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 9.28667e-18/99.0507,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00778894/99.0507,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00829372/99.0507,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00993994/99.0507,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0100758/99.0507,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00807071/99.0507,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00860242/99.0507,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00756673/99.0507,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 0.551678,mean = 3101.95,n = 145.628,sig_frac = 0.893968,sigma1 = 39.5155,sigma2 = 77.4552)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3135.79), !jacList=(), !facList=(), !func=cb=0.908993/254.352, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (74452.6) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=0.551678	mean=3101.95	n=145.628	sig_frac=0.893968	sigma1=39.4592	sigma2=77.865
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=2986.26, m0=mean=3101.95, sigma=sigma2=77.865, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3048.03, m0=mean=3101.95, sigma=sigma2=77.865, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2794.21, m0=mean=3101.95, sigma=sigma2=77.865, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.57, m0=mean=3101.95, sigma=sigma2=77.865, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3045.06, m0=mean=3101.95, sigma=sigma2=77.865, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3037.62, m0=mean=3101.95, sigma=sigma2=77.865, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3058.96, m0=mean=3101.95, sigma=sigma2=77.865, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=2881.4, m0=mean=3101.95, sigma=sigma2=77.865, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3056.33, m0=mean=3101.95, sigma=sigma2=77.865, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3042.26, m0=mean=3101.95, sigma=sigma2=77.865, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3041.96, m0=mean=3101.95, sigma=sigma2=77.865, alpha=alpha=0.551678, n=n=145.628
#      p.d.f value is Not-a-Number @ m=dimuon_M=3011.31, m0=mean=3101.95, sigma=sigma2=77.865, alpha=alpha=0.551678, n=n=145.628
#     ... (remaining 2038 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0097045/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00806864/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00878441/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0101067/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 8.4249e-18/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00779428/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00830089/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00995367/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0100901/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00807705/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00861076/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00757128/98.9096,cb = -nan/-nan), !coefficients=(sig_frac = 0.893968)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 0.551678,mean = 3101.95,n = 145.628,sig_frac = 0.893968,sigma1 = 39.4592,sigma2 = 77.865)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3135.79), !jacList=(), !facList=(), !func=cb=0.909904/255.606, !sumCat=()
#
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=73193.9 FROM HESSE     STATUS=OK             44 CALLS         698 TOTAL
#                      EDM=0.00162127    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        5.51678e-01   3.61324e-02   2.18344e-03  -7.11470e-01
#    2  mean         3.10195e+03   3.79877e-01   2.32153e-03  -2.87777e-02
#    3  n            1.24374e+02   8.11474e-01   5.00000e-01  -1.50314e-02
#    4  sig_frac     8.93968e-01   8.67853e-03   2.84028e-03   1.97514e+00
#    5  sigma1       3.94592e+01   3.78710e-01   1.44388e-03  -4.06644e+00
#    6  sigma2       7.74552e+01   2.81041e+00   3.38741e-02   4.98926e-02
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=73193.9 FROM MIGRAD    STATUS=CONVERGED     710 CALLS         711 TOTAL
#                      EDM=2.09114e-06    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   0.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        5.52819e-01   3.62158e-02   5.52126e-04   7.34175e-02
#    2  mean         3.10195e+03   3.79984e-01   2.98107e-05  -2.08644e-02
#    3  n            1.24374e+02   8.11472e-01  -1.06854e-06  -1.28420e-02
#    4  sig_frac     8.93570e-01   8.83718e-03  -1.29258e-03   1.11019e-01
#    5  sigma1       3.94587e+01   3.78818e-01  -1.30166e-05  -5.04428e-02
#    6  sigma2       7.73663e+01   2.87109e+00  -6.99066e-03  -2.16050e-03
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  6    ERR DEF=0.5
#   1.312e-03 -1.359e-03 -1.207e-05 -2.134e-04 -6.418e-03 -3.965e-03
#  -1.359e-03  1.444e-01  4.962e-04 -1.282e-04 -1.627e-03 -1.877e-01
#  -1.207e-05  4.962e-04  6.585e-01  3.190e-05  1.512e-03  1.111e-02
#  -2.134e-04 -1.282e-04  3.190e-05  7.812e-05  1.990e-03  1.243e-02
#  -6.418e-03 -1.627e-03  1.512e-03  1.990e-03  1.435e-01  2.050e-01
#  -3.965e-03 -1.877e-01  1.111e-02  1.243e-02  2.050e-01  8.385e+00
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6
#         1  0.74686   1.000 -0.099 -0.000 -0.667 -0.468 -0.038
#         2  0.20526  -0.099  1.000  0.002 -0.038 -0.011 -0.171
#         3  0.00728  -0.000  0.002  1.000  0.004  0.005  0.005
#         4  0.84403  -0.667 -0.038  0.004  1.000  0.594  0.486
#         5  0.60781  -0.468 -0.011  0.005  0.594  1.000  0.187
#         6  0.63044  -0.038 -0.171  0.005  0.486  0.187  1.000
#  **********
#  **   16 **SET ERR         0.5
#  **********
#  **********
#  **   17 **SET PRINT           1
#  **********
#  **********
#  **   18 **HESSE        3000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=73193.9 FROM HESSE     STATUS=OK             48 CALLS         759 TOTAL
#                      EDM=0.00695863    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  alpha        5.52819e-01   4.06204e-02   2.18119e-03  -1.13973e+00
#    2  mean         3.10195e+03   3.80620e-01   2.32085e-03   6.51398e-02
#    3  n            1.24374e+02   8.42095e+01   2.63287e-03   7.33314e-01
#    4  sig_frac     8.93570e-01   8.91420e-03   2.83765e-03   9.06158e-01
#    5  sigma1       3.94587e+01   3.80783e-01   1.44267e-03  -3.95301e-02
#    6  sigma2       7.73663e+01   2.86627e+00   1.35496e-02   1.16544e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  6    ERR DEF=0.5
#   1.650e-03 -1.575e-03 -6.968e+00 -2.374e-04 -6.930e-03 -8.866e-03
#  -1.575e-03  1.449e-01  3.086e+00 -1.181e-04 -1.573e-03 -1.896e-01
#  -6.968e+00  3.086e+00  1.400e+05  5.758e-01  1.247e+01  1.217e+02
#  -2.374e-04 -1.181e-04  5.758e-01  7.949e-05  2.030e-03  1.287e-02
#  -6.930e-03 -1.573e-03  1.247e+01  2.030e-03  1.450e-01  2.122e-01
#  -8.866e-03 -1.896e-01  1.217e+02  1.287e-02  2.122e-01  8.356e+00
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6
#         1  0.80513   1.000 -0.102 -0.458 -0.655 -0.448 -0.076
#         2  0.21218  -0.102  1.000  0.022 -0.035 -0.011 -0.172
#         3  0.53887  -0.458  0.022  1.000  0.173  0.088  0.112
#         4  0.85045  -0.655 -0.035  0.173  1.000  0.598  0.499
#         5  0.61202  -0.448 -0.011  0.088  0.598  1.000  0.193
#         6  0.64682  -0.076 -0.172  0.112  0.499  0.193  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %% [markdown]
# Facemos o plot dos resultados para comprobar visualmente

# %%
frame = mass.frame(ROOT.RooFit.Title(""))

roo_data.plotOn(frame)
signal.plotOn(frame)   

c = ROOT.TCanvas()
frame.SetTitle("")
frame.Draw()

title_text = ROOT.TLatex()
title_text.SetNDC()              # Usa coordenadas da pantalla (0 a 1) no canto das dos eixes
title_text.SetTextSize(0.045)    # Tamaño do texto
title_text.SetTextFont(62)       # Tipo de letra (62 adoita ser negrita en ROOT)
title_text.SetTextAlign(21)      # Aliñación: 2 (centro horizontal), 1 (abaixo vertical)

# Debuxamos o título na posición X=0.5 (centro) e Y=0.92 (arriba do todo)
title_text.DrawLatex(0.5, 0.92, "Axustes VM OO (MC)")
c.Draw()
