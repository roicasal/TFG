# %%
import ROOT
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ROOT.EnableImplicitMT(10)

# %% [markdown]
# Cargamos primeiro MC para ter o sinal

# %%
pathmc = '/rxc_lustre/ivan.cambon/TrackCalibmu_AA_tuples/MC/OO_2025/trackeffmu_OO_mc_2025.root'


tdf_mc = ROOT.RDataFrame("charmonium_mu_mu_Down_mup_Tag/DecayTree", pathmc)
sinal = tdf_mc.Filter("abs(mup_MC_MOTHER_ID == 443 & mum_MC_MOTHER_ID == 443)")

# %% [markdown]
# Cargamos agora todas as tuplas de data

# %%
pathdata = "/rxc_lustre/ivan.cambon/TrackCalibmu_AA_tuples/data/OO_2025/00319259_*_1.trackeff_muons_oo.root"
tdf = ROOT.RDataFrame("charmonium_mu_mu_Down_mup_Tag/DecayTree", pathdata)

# %% [markdown]
# Creamos o background

# %%
background = tdf.Filter("dimuon_M < 2850 | dimuon_M > 3350")

# %% [markdown]
# Ploteamos sinal vs background

# %%
# Crear histogramas (RResultPtr)
h_sinal = sinal.Histo1D(("h_sinal","Dimuon mass sinal",100,2600,3600), "dimuon_M")
h_background  = background.Histo1D(("h_background","Dimuon mass background",100,2600,3600), "dimuon_M")

# Converter a TH1 reais
hist_sinal = h_sinal.GetValue()
hist_bkg  = h_background.GetValue()

# Debuxar
c = ROOT.TCanvas("c", "Dimuon mass", 800, 600)

hist_sinal.SetLineColor(ROOT.kRed)
hist_sinal.SetLineWidth(2)

hist_bkg.SetLineColor(ROOT.kBlack)
hist_bkg.SetLineWidth(2)

# Debuxamos normalizado
hist_sinal.DrawNormalized("HIST")
hist_bkg.DrawNormalized("HIST SAME")

# Lenda
leg = ROOT.TLegend(0.75, 0.8, 0.92, 0.92)
leg.AddEntry(hist_sinal, "Sinal", "l")
leg.AddEntry(hist_bkg, "Background", "l")
leg.Draw()

# Estilo LHCb
ROOT.gROOT.ProcessLine(".L lhcbStyle.C")
ROOT.lhcbStyle()

c.Draw()
c.SaveAs("dimuon_mass_Down_sinal_vs_bkg.png")
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# -------------------------
# Set LHCb Style - May 2021
# -------------------------
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file dimuon_mass_Down_sinal_vs_bkg.png has been created

# %% [markdown]
# O seguinte é plotear agora as variables para poder ver que cortes facer. Para iso creamos primeiro un dicionario e a continuación un bucle que recorra as variables para ilas ploteando todas nunha carpeta

# %%
import os
outdir = "plots_variables"
os.makedirs(outdir, exist_ok=True)

ROOT.gROOT.ProcessLine(".L lhcbStyle.C")
ROOT.lhcbStyle()


variables = [
    'mup_CHI2DOF', 'mup_P', 'mup_BPVIPCHI2',
    'mum_CHI2DOF', 'mum_P', 'mum_PT',
    'mum_BPVIP', 'mum_BPVIPCHI2', 'mum_GHOSTPROB',
    'dimuon_DOCA_12', 'dimuon_BPVIP',
    'dimuon_CHI2DOF', 'dimuon_PT', 'mum_PID_MU', 'dimuon_M'
]


var_cfg = {

    # ===== Mu+ (tag ou probe segundo o caso) =====
    "mup_CHI2DOF": {
        "bins": 100,
        "xmin": 0,
        "xmax": 4,
        "xlabel": r"$\chi^2/\mathrm{ndof}(\mu^+)$"
    },

    "mup_P": {
        "bins": 100,
        "xmin": 0,
        "xmax": 120000,   # MeV
        "xlabel": r"$p(\mu^+)$ [MeV/c]"
    },

    "mup_BPVIPCHI2": {
        "bins": 100,
        "xmin": 0,
        "xmax": 30,
        "xlabel": r"$\chi^2_{\mathrm{IP}}(\mu^+)$"
    },

    # ===== Mu− =====
    "mum_CHI2DOF": {
        "bins": 100,
        "xmin": 0,
        "xmax": 3,
        "xlabel": r"$\chi^2/\mathrm{ndof}(\mu^-)$"
    },

    "mum_P": {
        "bins": 100,
        "xmin": 0,
        "xmax": 100000,
        "xlabel": r"$p(\mu^-)$ [MeV/c]"
    },

    "mum_PT": {
        "bins": 100,
        "xmin": 0,
        "xmax": 10000,
        "xlabel": r"$p_T(\mu^-)$ [MeV/c]"
    },

    "mum_BPVIP": {
        "bins": 100,
        "xmin": 0,
        "xmax": 1.0,      # mm
        "xlabel": r"$\mathrm{IP}(\mu^-)$ [mm]"
    },

    "mum_BPVIPCHI2": {
        "bins": 100,
        "xmin": 0,
        "xmax": 100,
        "xlabel": r"$\chi^2_{\mathrm{IP}}(\mu^-)$"
    },

    "mum_GHOSTPROB": {
        "bins": 100,
        "xmin": 0,
        "xmax": 0.3,
        "xlabel": r"$\mathrm{GhostProb}(\mu^-)$"
    },

    "mum_PID_MU": {
        "bins": 100,
        "xmin": -10,
        "xmax": 10,
        "xlabel": r"$\mathrm{PID}_\mu(\mu^-)$"
    },

    # ===== Dimuon =====
    "dimuon_DOCA_12": {
        "bins": 100,
        "xmin": 0,
        "xmax": 1.5,      # mm
        "xlabel": r"$\mathrm{DOCA}(\mu^+\mu^-)$ [mm]"
    },

    "dimuon_BPVIP": {
        "bins": 100,
        "xmin": 0,
        "xmax": 1.5,
        "xlabel": r"$\mathrm{IP}(\mu^+\mu^-)$ [mm]"
    },

    "dimuon_CHI2DOF": {
        "bins": 100,
        "xmin": 0,
        "xmax": 3,
        "xlabel": r"$\chi^2/\mathrm{ndof}(\mu^+\mu^-)$"
    },

    "dimuon_PT": {
        "bins": 100,
        "xmin": 0,
        "xmax": 10000,
        "xlabel": r"$p_T(\mu^+\mu^-)$ [MeV/c]"
    },

    "dimuon_M": {
        "bins": 120,
        "xmin": 2600,
        "xmax": 3600,
        "xlabel": r"$m(\mu^+\mu^-)$ [MeV/c^2]"
    },
}



for var in variables:

    cfg = var_cfg[var]

    bins = cfg["bins"]
    xmin = cfg["xmin"]
    xmax = cfg["xmax"]
    xlabel = cfg["xlabel"]

    # histogramas RDataFrame
    h_mc  = tdf_mc.Histo1D((f"h_mc_{var}", "", bins, xmin, xmax), var)
    h_bkg = background.Histo1D((f"h_bkg_{var}", "", bins, xmin, xmax), var)    # converter a TH1 reais
    hist_mc  = h_mc.GetValue()
    hist_bkg = h_bkg.GetValue()

    # estilo
    hist_mc.SetLineColor(ROOT.kBlue)
    hist_mc.SetLineWidth(2)

    hist_bkg.SetLineColor(ROOT.kRed)
    hist_bkg.SetLineWidth(2)

    hist_mc.GetXaxis().SetTitle(xlabel)
    hist_mc.GetYaxis().SetTitle("Normalized events")

    # canvas
    c = ROOT.TCanvas(f"c_{var}", var, 800, 600)

    hist_mc.DrawNormalized("HIST")
    hist_bkg.DrawNormalized("HIST SAME")

    # lenda
    leg = ROOT.TLegend(0.70,0.75,0.90,0.90)
    leg.AddEntry(hist_mc, "MC", "l")
    leg.AddEntry(hist_bkg, "Background", "l")
    leg.Draw()

    c.SaveAs(f"{outdir}/{var}.png")
# Out:
# -------------------------
# Set LHCb Style - May 2021
# -------------------------
# Info in <TCanvas::Print>: png file plots_variables/mup_CHI2DOF.png has been created
# Info in <TCanvas::Print>: png file plots_variables/mup_P.png has been created
# Info in <TCanvas::Print>: png file plots_variables/mup_BPVIPCHI2.png has been created
# Info in <TCanvas::Print>: png file plots_variables/mum_CHI2DOF.png has been created
# Info in <TCanvas::Print>: png file plots_variables/mum_P.png has been created
# Info in <TCanvas::Print>: png file plots_variables/mum_PT.png has been created
# Info in <TCanvas::Print>: png file plots_variables/mum_BPVIP.png has been created
# Info in <TCanvas::Print>: png file plots_variables/mum_BPVIPCHI2.png has been created
# Info in <TCanvas::Print>: png file plots_variables/mum_GHOSTPROB.png has been created
# Info in <TCanvas::Print>: png file plots_variables/dimuon_DOCA_12.png has been created
# Info in <TCanvas::Print>: png file plots_variables/dimuon_BPVIP.png has been created
# Info in <TCanvas::Print>: png file plots_variables/dimuon_CHI2DOF.png has been created
# Info in <TCanvas::Print>: png file plots_variables/dimuon_PT.png has been created
# Info in <TCanvas::Print>: png file plots_variables/mum_PID_MU.png has been created
# Info in <TCanvas::Print>: png file plots_variables/dimuon_M.png has been created

# %% [markdown]
# Unha vez temos todas as variables polteadas procedemos a facer os cortes convenientes para eliminar o background no sample de datos

# %%
dataMupDowntag_bkg = tdf.Filter("dimuon_BPVIP < 0.35 && dimuon_DOCA_12 < 0.5 &&  dimuon_PT > 2000 && mum_CHI2DOF < 1.5 && mum_P > 1000 && mum_PID_MU > 0 && mum_PT > 1500 && mup_CHI2DOF < 1.2")

# %% [markdown]
# Imos plotear entón agora o sample de datos sen ningún corte vs o sample cortado. Deberíase apreciar un pico en torno á masa do J/psi

# %%
# Crear histogramas (RResultPtr)
h_mass_before = tdf.Histo1D(("h_mass_before","Dimuon mass before cuts",100,2600,3600), "dimuon_M")
h_mass_after  = dataMupDowntag_bkg.Histo1D(("h_mass_after","Dimuon mass after cuts",100,2600,3600), "dimuon_M")

# Converter a TH1 reais
hist_before = h_mass_before.GetValue()
hist_after  = h_mass_after.GetValue()

# Debuxar
c = ROOT.TCanvas("c", "Dimuon mass", 800, 600)

hist_before.SetLineColor(ROOT.kBlack)
hist_before.SetLineWidth(2)

hist_after.SetLineColor(ROOT.kRed)
hist_after.SetLineWidth(2)

# Debuxamos normalizado
hist_after.DrawNormalized("HIST")
hist_before.DrawNormalized("HIST SAME")

# Lenda
leg = ROOT.TLegend(0.75, 0.8, 0.92, 0.92)
leg.AddEntry(hist_before, "Datos crus", "l")
leg.AddEntry(hist_after, "Datos post cortes", "l")
leg.Draw()

# Estilo LHCb
ROOT.gROOT.ProcessLine(".L lhcbStyle.C")
ROOT.lhcbStyle()

c.Draw()
c.SaveAs("dimuon_mass_Down_corte_vs_uncut.png")
# Out:
# -------------------------
# Set LHCb Style - May 2021
# -------------------------
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file dimuon_mass_Down_corte_vs_uncut.png has been created

# %% [markdown]
# Unha vez se ve o pico na masa como queremos, procedemos a crear os samples tag (todos os candidatos), match (o VELO foi quen de detectalo) e o fail (o VELO non o detectou)

# %%
match = dataMupDowntag_bkg.Filter("nMatch > 0")
fail = dataMupDowntag_bkg.Filter("nMatch == 0")
tag = dataMupDowntag_bkg

# %% [markdown]
# Ploteamos estes samples para ver como quedan

# %%
c = ROOT.TCanvas("c", "", 800, 600)
h_tag   = dataMupDowntag_bkg.Histo1D(("tag","",100,2800,3400),"dimuon_M")
h_match = match.Histo1D(("match","",100,2800,3400),"dimuon_M")
h_fail  = fail.Histo1D(("fail","",100,2800,3400),"dimuon_M")

hist_tag   = h_tag.GetValue()
hist_match = h_match.GetValue()
hist_fail  = h_fail.GetValue()

hist_tag.SetLineColor(ROOT.kBlack)
hist_match.SetLineColor(ROOT.kBlue)
hist_fail.SetLineColor(ROOT.kRed)

hist_tag.GetXaxis().SetTitle("m_{#mu#mu} [MeV/c^{2}]")
hist_tag.GetYaxis().SetTitle("Eventos")
hist_tag.SetMinimum(0)
hist_tag.Draw("HIST")
hist_match.Draw("HIST SAME")
hist_fail.Draw("HIST SAME")

leg = ROOT.TLegend(0.65, 0.75, 0.9, 0.9)
leg.SetBorderSize(0)
leg.SetFillStyle(0)
leg.AddEntry(hist_tag,   "Tag",   "l")
leg.AddEntry(hist_match, "Match", "l")
leg.AddEntry(hist_fail,  "Fail",  "l")
leg.Draw()

ROOT.gROOT.ProcessLine(".L lhcbStyle.C")
ROOT.lhcbStyle()

c.Draw()
c.SaveAs("OO_match_vs_fail_Down.png")
# Out:
# -------------------------
# Set LHCb Style - May 2021
# -------------------------
# Info in <TCanvas::Print>: png file OO_match_vs_fail_Down.png has been created

# %% [markdown]
# Pasamos agora a facer os fits. Para traballar con RooFit primeiro temos que definir a variable que imos usar e ler os datos con ROOT.RooDataSet.from_numpy

# %%
mass = ROOT.RooRealVar("dimuon_M", "m(#mu#mu) [MeV/c^{2}]", 2800, 3400) 

data_match = match.AsNumpy(["dimuon_M"])
roo_data_match = ROOT.RooDataSet.from_numpy(
    {"dimuon_M": data_match["dimuon_M"]},
    [mass]
)

data_fail = fail.AsNumpy(["dimuon_M"])
roo_data_fail = ROOT.RooDataSet.from_numpy(
    {"dimuon_M": data_fail["dimuon_M"]},
    [mass])


data_tag = dataMupDowntag_bkg.AsNumpy(["dimuon_M"])
roo_data_tag = ROOT.RooDataSet.from_numpy(
    {"dimuon_M": data_tag["dimuon_M"]},
    [mass]
)
# Out:
# [#0] WARNING:DataHandling -- RooDataSet.from_numpy() Ignored 143905 out-of-range events
# [#0] WARNING:DataHandling -- RooDataSet.from_numpy() Ignored 6420 out-of-range events
# [#0] WARNING:DataHandling -- RooDataSet.from_numpy() Ignored 150325 out-of-range events

# %% [markdown]
# Unha vez definida a variable de masa, pasamos cos plots. Para o sample match usamos un axuste a unha exponencial+gaussiana+CB

# %%
# SAMPLE MATCH
alpha = ROOT.RooRealVar("alpha", "alpha", 1.99966)
alpha.setConstant(True) # ¡Moi importante! Isto evita que MINUIT os toque
n = ROOT.RooRealVar("n", "n", 2.5)
n.setConstant(True)

# 3. Parámetros LIBRES (inicializados cos valores do MC pero con marxe)
mean   = ROOT.RooRealVar("mean", "mean", 3098.32, 3070, 3130)
# Damos un pouco máis de límite superior aos sigmas porque os datos reais teñen peor resolución
sigma1 = ROOT.RooRealVar("sigma1", "sigma gauss", 13.51, 5, 25)  
sigma2 = ROOT.RooRealVar("sigma2", "sigma cb", 26.76, 15, 300)
sig_frac = ROOT.RooRealVar("sig_frac", "fraction Gauss/CB", 0.714, 0, 1)

# 4. Construción do sinal
gauss = ROOT.RooGaussian("gauss", "Gaussian", mass, mean, sigma1)
cb    = ROOT.RooCBShape("cb", "Crystal Ball", mass, mean, sigma2, alpha, n)
signal = ROOT.RooAddPdf("signal", "Gauss + CB", [gauss, cb], [sig_frac])

# 5. Parámetros LIBRES do Fondo
tau = ROOT.RooRealVar("tau", "tau bkg", -0.0127, -1.0, 0.5)
bkg = ROOT.RooExponential("bkg", "Exponential Bkg", mass, tau)

# 6. Yields (Número de eventos). Subimos moito os límites iniciais porque tes máis datos
nsig = ROOT.RooRealVar("nsig", "N signal", 28000, 0, 200000)
nbkg = ROOT.RooRealVar("nbkg", "N background", 20000, 0, 200000)

# 7. Modelo Total e Axuste
model_total = ROOT.RooAddPdf("model_total", "Signal + Background", [signal, bkg], [nsig, nbkg])

# Asumindo que os teus datos de 'match' están nun RooDataSet ou RooDataHist chamado roo_data_match
model_total.fitTo(roo_data_match)
# Out:
# <cppyy.gbl.RooFitResult object at 0x(nil)>
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (gauss,cb,bkg)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 mean         3.09832e+03  6.00000e+00    3.07000e+03  3.13000e+03
#      2 nbkg         2.00000e+04  1.00000e+04    0.00000e+00  2.00000e+05
#      3 nsig         2.80000e+04  1.40000e+04    0.00000e+00  2.00000e+05
#      4 sig_frac     7.14000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      5 sigma1       1.35100e+01  2.00000e+00    5.00000e+00  2.50000e+01
#      6 sigma2       2.67600e+01  5.88000e+00    1.50000e+01  3.00000e+02
#      7 tau         -1.27000e-02  1.50000e-01   -1.00000e+00  5.00000e-01
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        3500           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-958742 FROM MIGRAD    STATUS=INITIATE      198 CALLS         199 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  mean         3.09832e+03   6.00000e+00   0.00000e+00  -1.96873e+03
#    2  nbkg         2.00000e+04   1.00000e+04   0.00000e+00  -2.98162e+05
#    3  nsig         2.80000e+04   1.40000e+04   0.00000e+00  -2.13956e+05
#    4  sig_frac     5.12897e-03   1.00000e-01   1.27964e-01   1.45120e+01
#    5  sigma1       5.01027e+00   2.00000e+00   0.00000e+00   1.15980e+00
#    6  sigma2       1.00446e+02   5.88000e+00   0.00000e+00  -6.55801e+04
#    7  tau         -2.38394e-03   1.50000e-01   0.00000e+00  -8.77523e+05
#                                ERR DEF= 0.5
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 5 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== 1.04827 added to diagonal of error matrix
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (850841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=3074.08	nbkg=38224.8	nsig=186207	sig_frac=0.0293877	sigma1=9.28962	sigma2=27.2295	tau=0.49554
# RooAddPdf::model_total[ nsig * signal + nbkg * bkg ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00129889/1,bkg = -nan/-nan), !coefficients=(nsig = 186207,nbkg = 38224.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 1.69921e-05/1,bkg = -nan/-nan), !coefficients=(nsig = 186207,nbkg = 38224.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000193234/1,bkg = -nan/-nan), !coefficients=(nsig = 186207,nbkg = 38224.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 6.22461e-21/1,bkg = -nan/-nan), !coefficients=(nsig = 186207,nbkg = 38224.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0133903/1,bkg = -nan/-nan), !coefficients=(nsig = 186207,nbkg = 38224.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000872629/1,bkg = -nan/-nan), !coefficients=(nsig = 186207,nbkg = 38224.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00595599/1,bkg = -nan/-nan), !coefficients=(nsig = 186207,nbkg = 38224.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00140482/1,bkg = -nan/-nan), !coefficients=(nsig = 186207,nbkg = 38224.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 5.60272e-05/1,bkg = -nan/-nan), !coefficients=(nsig = 186207,nbkg = 38224.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000106784/1,bkg = -nan/-nan), !coefficients=(nsig = 186207,nbkg = 38224.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000270277/1,bkg = -nan/-nan), !coefficients=(nsig = 186207,nbkg = 38224.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 7.23323e-11/1,bkg = -nan/-nan), !coefficients=(nsig = 186207,nbkg = 38224.8)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_model_total_[ parameters=(alpha,mean,n,nbkg,nsig,sig_frac,sigma1,sigma2,tau) ]
#      function value is NAN @ parameters=(alpha = 1.99966,mean = 3074.08,n = 2.5,nbkg = 38224.8,nsig = 186207,sig_frac = 0.0293877,sigma1 = 9.28962,sigma2 = 27.2295,tau = 0.49554)
# RooRealIntegral::bkg_Int[dimuon_M][ Int bkgd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3067.6), !jacList=(), !facList=(), !func=bkg=inf/6.43803, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (850841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mean=3072.89	nbkg=109710	nsig=185097	sig_frac=0.995847	sigma1=17.1779	sigma2=210.781	tau=0.475905
# RooAddPdf::model_total[ nsig * signal + nbkg * bkg ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 7.5572e-05/1,bkg = -nan/-nan), !coefficients=(nsig = 185097,nbkg = 109710)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 4.79625e-06/1,bkg = -nan/-nan), !coefficients=(nsig = 185097,nbkg = 109710)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 8.26678e-06/1,bkg = -nan/-nan), !coefficients=(nsig = 185097,nbkg = 109710)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 4.58128e-06/1,bkg = -nan/-nan), !coefficients=(nsig = 185097,nbkg = 109710)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0177609/1,bkg = -nan/-nan), !coefficients=(nsig = 185097,nbkg = 109710)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 2.47275e-05/1,bkg = -nan/-nan), !coefficients=(nsig = 185097,nbkg = 109710)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00314858/1,bkg = -nan/-nan), !coefficients=(nsig = 185097,nbkg = 109710)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 9.36942e-05/1,bkg = -nan/-nan), !coefficients=(nsig = 185097,nbkg = 109710)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 7.04285e-06/1,bkg = -nan/-nan), !coefficients=(nsig = 185097,nbkg = 109710)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 7.79401e-06/1,bkg = -nan/-nan), !coefficients=(nsig = 185097,nbkg = 109710)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 8.47318e-06/1,bkg = -nan/-nan), !coefficients=(nsig = 185097,nbkg = 109710)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 6.75944e-06/1,bkg = -nan/-nan), !coefficients=(nsig = 185097,nbkg = 109710)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_model_total_[ parameters=(alpha,mean,n,nbkg,nsig,sig_frac,sigma1,sigma2,tau) ]
#      function value is NAN @ parameters=(alpha = 1.99966,mean = 3072.89,n = 2.5,nbkg = 109710,nsig = 185097,sig_frac = 0.995847,sigma1 = 17.1779,sigma2 = 210.781,tau = 0.475905)
# RooRealIntegral::bkg_Int[dimuon_M][ Int bkgd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3067.6), !jacList=(), !facList=(), !func=bkg=inf/-0, !sumCat=()
#
#  MIGRAD FAILS TO FIND IMPROVEMENT
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -1.5658e+01  1.3987e-02  6.7789e-01  1.0248e+00  1.2099e+00  1.9565e+00  1.7775e+01
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 15.675710 TO DIAGONAL.
#  FCN=-1.16456e+06 FROM HESSE     STATUS=NOT POSDEF     50 CALLS         513 TOTAL
#                      EDM=341613    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  mean         3.07861e+03   5.23466e+01   1.24116e-01   3.86127e+02
#    2  nbkg         1.33253e+05   1.18444e+02   3.74717e-03   4.33581e+02
#    3  nsig         1.01740e+05   1.17806e+02   3.56704e-03   6.55459e+02
#    4  sig_frac     2.94424e-02   1.27702e-02   1.21344e-02  -1.99037e+03
#    5  sigma1       1.97402e+01   3.31918e+00   7.93037e-02   5.50012e+01
#    6  sigma2       2.89054e+02   6.93226e-01   3.72638e-02   8.91757e+01
#    7  tau         -1.45747e-03   1.81694e-05   2.22912e-05   1.96037e+05
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-1.16558e+06 FROM MIGRAD    STATUS=CONVERGED    1294 CALLS        1295 TOTAL
#                      EDM=0.000116931    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  mean         3.09492e+03   3.99879e-01   1.00202e-02   6.91458e-02
#    2  nbkg         2.00000e+05   7.58375e+02   6.94582e-02** at limit **
#    3  nsig         3.35805e+04   6.49120e+02   3.95595e-03   9.41803e-02
#    4  sig_frac     2.92052e-01   8.91439e-03   9.24996e-03  -6.95632e-03
#    5  sigma1       1.62403e+01   4.20499e-01   2.61844e-02   2.52258e-01
#    6  sigma2       3.00000e+02   4.47224e+00   1.86862e-01** at limit **
#    7  tau         -1.13463e-03   1.41979e-05   1.45020e-05   2.42972e+01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  7    ERR DEF=0.5
#   1.599e-01 -5.688e-04 -1.151e+00  1.459e-04  1.420e-02 -8.473e-06  4.112e-07
#  -5.688e-04  1.970e-01  1.914e+02 -1.845e-03 -7.641e-03 -6.429e-05 -1.062e-06
#  -1.151e+00  1.914e+02  4.214e+05 -3.739e+00 -1.549e+01 -1.303e-01 -2.151e-03
#   1.459e-04 -1.845e-03 -3.739e+00  7.948e-05  1.721e-03 -1.628e-06  2.126e-08
#   1.420e-02 -7.641e-03 -1.549e+01  1.721e-03  1.769e-01 -1.125e-04  1.324e-07
#  -8.473e-06 -6.429e-05 -1.303e-01 -1.628e-06 -1.125e-04  4.623e-05  1.274e-09
#   4.112e-07 -1.062e-06 -2.151e-03  2.126e-08  1.324e-07  1.274e-09  2.016e-10
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7
#         1  0.11142   1.000 -0.003 -0.004  0.041  0.084 -0.003  0.072
#         2  0.66701  -0.003  1.000  0.665 -0.466 -0.041 -0.021 -0.168
#         3  0.79156  -0.004  0.665  1.000 -0.646 -0.057 -0.030 -0.233
#         4  0.77434   0.041 -0.466 -0.646  1.000  0.459 -0.027  0.168
#         5  0.55993   0.084 -0.041 -0.057  0.459  1.000 -0.039  0.022
#         6  0.06836  -0.003 -0.021 -0.030 -0.027 -0.039  1.000  0.013
#         7  0.24561   0.072 -0.168 -0.233  0.168  0.022  0.013  1.000
#  **********
#  **    7 **SET ERR         0.5
#  **********
#  **********
#  **    8 **SET PRINT           1
#  **********
#  **********
#  **    9 **HESSE        3500
#  **********
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -1.1625e-02  4.8399e-01  9.3149e-01  1.0000e+00  1.0786e+00  1.4465e+00  2.0711e+00
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 0.013696 TO DIAGONAL.
#  FCN=-1.16558e+06 FROM HESSE     STATUS=NOT POSDEF     56 CALLS        1351 TOTAL
#                      EDM=0.00012234    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE     INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  mean         3.09492e+03   3.96946e-01   4.00810e-04   3.31173e+00
#    2  nbkg         2.00000e+05   2.81626e+03   5.00000e-01   1.57076e+00
#                                  WARNING -   - ABOVE PARAMETER IS AT LIMIT.
#    3  nsig         3.35805e+04   5.93048e+03   1.58238e-04  -7.26416e-01
#    4  sig_frac     2.92052e-01   5.57712e-02   3.69998e-04  -4.28928e-01
#    5  sigma1       1.62403e+01   4.42000e-01   1.04737e-03   1.24346e-01
#    6  sigma2       3.00000e+02   4.53226e+00   7.47446e-03   1.57061e+00
#                                  WARNING -   - ABOVE PARAMETER IS AT LIMIT.
#    7  tau         -1.13463e-03   3.55257e-05   5.80078e-07   3.38233e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  7    ERR DEF=0.5
#   1.576e-01 -7.795e-03 -5.415e+01  6.371e-04  1.377e-02  4.007e-07  6.930e-07
#  -7.795e-03  7.340e-01  5.070e+03 -4.744e-02 -1.275e-01 -6.845e-05 -2.801e-05
#  -5.415e+01  5.070e+03  3.524e+07 -3.295e+02 -8.856e+02 -4.754e-01 -1.946e-01
#   6.371e-04 -4.744e-02 -3.295e+02  3.126e-03  9.829e-03  4.338e-06  1.821e-06
#   1.377e-02 -1.275e-01 -8.856e+02  9.829e-03  1.955e-01  7.469e-06  4.937e-06
#   4.007e-07 -6.845e-05 -4.754e-01  4.338e-06  7.469e-06  4.685e-05  2.648e-09
#   6.930e-07 -2.801e-05 -1.946e-01  1.821e-06  4.937e-06  2.648e-09  1.262e-09
# ERR MATRIX NOT POS-DEF
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7
#         1  0.10665   1.000 -0.023 -0.023  0.029  0.078  0.000  0.049
#         2  0.99684  -0.023  1.000  0.997 -0.990 -0.337 -0.012 -0.920
#         3  0.99780  -0.023  0.997  1.000 -0.993 -0.337 -0.012 -0.922
#         4  0.99497   0.029 -0.990 -0.993  1.000  0.398  0.011  0.917
#         5  0.62210   0.078 -0.337 -0.337  0.398  1.000  0.002  0.314
#         6  0.01193   0.000 -0.012 -0.012  0.011  0.002  1.000  0.011
#         7  0.92301   0.049 -0.920 -0.922  0.917  0.314  0.011  1.000
#  ERR MATRIX NOT POS-DEF
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %% [markdown]
# Para o tag usaremos tamén o combo de exponencial + gaussiana + CB xa que ten a mesma forma que o match

# %%
# SAMPLE TAG
alpha_tag = ROOT.RooRealVar("alpha", "alpha", 1.99966)
alpha_tag.setConstant(True)
n_tag = ROOT.RooRealVar("n", "n", 49.53)
n_tag.setConstant(True)

# 2. Parámetros LIBRES do Tag (Poden variar lixeiramente respecto ao match)
mean_tag   = ROOT.RooRealVar("mean_tag", "mean", 3098.32, 3070, 3130)
sigma1_tag = ROOT.RooRealVar("sigma1_tag", "sigma gauss", 13.51, 5, 25)  
sigma2_tag = ROOT.RooRealVar("sigma2_tag", "sigma cb", 26.76, 15, 60)
sig_frac_tag = ROOT.RooRealVar("sig_frac_tag", "fraction Gauss/CB", 0.714, 0, 1)

# Construción do sinal do Tag
gauss_tag = ROOT.RooGaussian("gauss_tag", "Gaussian", mass, mean_tag, sigma1_tag)
cb_tag    = ROOT.RooCBShape("cb_tag", "Crystal Ball", mass, mean_tag, sigma2_tag, alpha_tag, n_tag)
signal_tag = ROOT.RooAddPdf("signal_tag", "Gauss + CB", [gauss_tag, cb_tag], [sig_frac_tag])

# 3. Parámetros LIBRES do Fondo do Tag
tau_tag = ROOT.RooRealVar("tau_tag", "tau bkg", -0.01274, -1.0, 0.5)
bkg_tag = ROOT.RooExponential("bkg_tag", "Exponential Bkg", mass, tau_tag)

# 4. Yields (Número de eventos). Lixeiramente superiores porque Tag = Match + Fail
nsig_tag = ROOT.RooRealVar("nsig_tag", "N signal tag", 30000, 0, 300000)
nbkg_tag = ROOT.RooRealVar("nbkg_tag", "N background tag", 25000, 0, 300000)

# 5. Modelo Total e Axuste á mostra TAG
model_tag = ROOT.RooAddPdf("model_tag", "Signal + Background Tag", [signal_tag, bkg_tag], [nsig_tag, nbkg_tag])

# Lanzamos o fit contra os datos que me dixeches
model_tag.fitTo(roo_data_tag)
# Out:
# <cppyy.gbl.RooFitResult object at 0x(nil)>
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (gauss_tag,cb_tag,bkg_tag)
#  **********
#  **   10 **SET PRINT           1
#  **********
#  **********
#  **   11 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 mean_tag     3.09832e+03  6.00000e+00    3.07000e+03  3.13000e+03
#      2 nbkg_tag     2.50000e+04  1.25000e+04    0.00000e+00  3.00000e+05
#      3 nsig_tag     3.00000e+04  1.50000e+04    0.00000e+00  3.00000e+05
#      4 sig_frac_tag   7.14000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      5 sigma1_tag   1.35100e+01  2.00000e+00    5.00000e+00  2.50000e+01
#      6 sigma2_tag   2.67600e+01  4.50000e+00    1.50000e+01  6.00000e+01
#      7 tau_tag     -1.27400e-02  1.50000e-01   -1.00000e+00  5.00000e-01
#  **********
#  **   12 **SET ERR         0.5
#  **********
#  **********
#  **   13 **SET PRINT           1
#  **********
#  **********
#  **   14 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   15 **MIGRAD        3500           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-1.00539e+06 FROM MIGRAD    STATUS=INITIATE      172 CALLS         173 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  mean_tag     3.09832e+03   6.00000e+00   0.00000e+00  -2.65617e+02
#    2  nbkg_tag     2.50000e+04   1.25000e+04   0.00000e+00  -4.43208e+05
#    3  nsig_tag     3.00000e+04   1.50000e+04   0.00000e+00  -1.64543e+05
#    4  sig_frac_tag   2.66511e-04   1.00000e-01   0.00000e+00   9.88201e+01
#    5  sigma1_tag   5.18117e+00   2.00000e+00   0.00000e+00  -3.21419e-01
#    6  sigma2_tag   6.00000e+01   4.50000e+00   0.00000e+00** at limit **
#    7  tau_tag     -1.98321e-03   1.50000e-01   1.51577e-02  -1.67103e+06
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 6 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== 1.44031 added to diagonal of error matrix
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-1.22418e+06 FROM HESSE     STATUS=OK             62 CALLS         548 TOTAL
#                      EDM=0.00088345    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  mean_tag     3.09494e+03   4.07517e-01   1.04473e-02   8.04445e-02
#    2  nbkg_tag     2.31712e+05   6.39382e+02   2.97866e-03  -1.26804e+00
#    3  nsig_tag     1.17656e+04   4.36471e+02   2.70814e-03  -1.81851e+00
#    4  sig_frac_tag   8.01472e-01   5.20616e-02   3.89530e-02  -1.59570e-01
#    5  sigma1_tag   1.59245e+01   5.93125e-01   2.72401e-02  -3.07915e-01
#    6  sigma2_tag   6.00000e+01   2.97612e+01   5.00000e-01** at limit **
#    7  tau_tag     -1.02877e-03   1.22251e-05   1.30914e-05  -1.31685e+02
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=-1.22418e+06 FROM MIGRAD    STATUS=CONVERGED     563 CALLS         564 TOTAL
#                      EDM=5.42621e-05    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   0.6 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  mean_tag     3.09494e+03   4.06818e-01  -5.77651e-05  -9.93878e-03
#    2  nbkg_tag     2.31703e+05   6.29376e+02  -6.78404e-05  -2.99460e-02
#    3  nsig_tag     1.17766e+04   4.23077e+02   1.88773e-04  -1.28468e+00
#    4  sig_frac_tag   7.99609e-01   4.61078e-02   4.66205e-03   1.17397e-01
#    5  sigma1_tag   1.59062e+01   5.37653e-01   1.84054e-03   1.75749e-02
#    6  sigma2_tag   5.99990e+01   2.97605e+01   9.32159e-03  -6.36226e-03
#    7  tau_tag     -1.02878e-03   1.22201e-05  -2.12136e-08  -6.27387e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  7    ERR DEF=0.5
#   1.655e-01 -1.576e-01  1.551e-01 -8.979e-04 -2.201e-02 -3.268e-03  2.404e-07
#  -1.576e-01  3.961e+05 -1.654e+05 -1.373e+01 -2.672e+01  2.198e+01  5.903e-04
#   1.551e-01 -1.654e+05  1.790e+05  1.385e+01  2.708e+01 -2.111e+01 -5.891e-04
#  -8.979e-04 -1.373e+01  1.385e+01  2.135e-03  1.510e-02  3.076e-03 -5.008e-08
#  -2.201e-02 -2.672e+01  2.708e+01  1.510e-02  2.894e-01  5.460e-02 -1.241e-07
#  -3.268e-03  2.198e+01 -2.111e+01  3.076e-03  5.460e-02  6.722e-02  8.330e-08
#   2.404e-07  5.903e-04 -5.891e-04 -5.008e-08 -1.241e-07  8.330e-08  1.493e-10
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7
#         1  0.11322   1.000 -0.001  0.001 -0.048 -0.101 -0.031  0.048
#         2  0.62625  -0.001  1.000 -0.621 -0.472 -0.079  0.135  0.077
#         3  0.87168   0.001 -0.621  1.000  0.709  0.119 -0.192 -0.114
#         4  0.90528  -0.048 -0.472  0.709  1.000  0.607  0.257 -0.089
#         5  0.75340  -0.101 -0.079  0.119  0.607  1.000  0.392 -0.019
#         6  0.59180  -0.031  0.135 -0.192  0.257  0.392  1.000  0.026
#         7  0.12514   0.048  0.077 -0.114 -0.089 -0.019  0.026  1.000
#  **********
#  **   16 **SET ERR         0.5
#  **********
#  **********
#  **   17 **SET PRINT           1
#  **********
#  **********
#  **   18 **HESSE        3500
#  **********
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 6 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== 1.71901 added to diagonal of error matrix
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-1.22418e+06 FROM HESSE     STATUS=OK             62 CALLS         626 TOTAL
#                      EDM=6.81457e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  mean_tag     3.09494e+03   4.06809e-01   4.17892e-03  -2.97210e+00
#    2  nbkg_tag     2.31703e+05   6.27035e+02   1.19147e-03   5.76016e-01
#    3  nsig_tag     1.17766e+04   4.16934e+02   1.08325e-03  -1.17190e+00
#    4  sig_frac_tag   7.99609e-01   4.89174e-02   1.55812e-02  -3.78412e+00
#    5  sigma1_tag   1.59062e+01   5.46076e-01   1.08960e-02  -3.23233e+00
#    6  sigma2_tag   5.99990e+01   2.78614e+01   2.00000e-01   1.58026e+00
#    7  tau_tag     -1.02878e-03   1.22172e-05   1.30914e-05   3.38382e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  7    ERR DEF=0.5
#   1.655e-01  2.726e+00 -2.732e+00 -1.209e-03 -2.303e-02 -7.893e-04  2.499e-07
#   2.726e+00  3.932e+05 -1.618e+05 -1.598e+01 -6.133e+01  8.432e+00  5.776e-04
#  -2.732e+00 -1.618e+05  1.738e+05  1.601e+01  6.148e+01 -8.450e+00 -5.787e-04
#  -1.209e-03 -1.598e+01  1.601e+01  2.405e-03  1.748e-02  6.722e-04 -5.750e-08
#  -2.303e-02 -6.133e+01  6.148e+01  1.748e-02  2.985e-01  1.441e-02 -2.386e-07
#  -7.893e-04  8.432e+00 -8.450e+00  6.722e-04  1.441e-02  4.803e-02  2.984e-08
#   2.499e-07  5.776e-04 -5.787e-04 -5.750e-08 -2.386e-07  2.984e-08  1.493e-10
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7
#         1  0.11508   1.000  0.011 -0.016 -0.061 -0.104 -0.009  0.050
#         2  0.62305   0.011  1.000 -0.619 -0.520 -0.179  0.061  0.075
#         3  0.86866  -0.016 -0.619  1.000  0.783  0.270 -0.092 -0.114
#         4  0.91062  -0.061 -0.520  0.783  1.000  0.652  0.063 -0.096
#         5  0.76126  -0.104 -0.179  0.270  0.652  1.000  0.120 -0.036
#         6  0.23742  -0.009  0.061 -0.092  0.063  0.120  1.000  0.011
#         7  0.12413   0.050  0.075 -0.114 -0.096 -0.036  0.011  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %% [markdown]
# Por último para o sample fail axustamos os datos a unha exponencial

# %%
# SAMPLE FAIL
#mass = ROOT.RooRealVar("mass", "m_{#mu#mu} [MeV/c^{2}]", 2800, 3400)

# 2. O parámetro da exponencial para o Fail
# Inicializámolo nun valor pequeno negativo.
tau_fail = ROOT.RooRealVar("tau_fail", "tau fail", -0.001, -0.02, 0.0)

# 3. A función Exponencial pura
bkg_fail = ROOT.RooExponential("bkg_fail", "Exponential Bkg Fail", mass, tau_fail)

# 4. Número de eventos (Yield). 
# Mirando a túa gráfica, a mostra fail ten moi poucos eventos en comparación co resto.
nbkg_fail = ROOT.RooRealVar("nbkg_fail", "N background fail", 1000, 0, 50000)

# 5. Creamos o modelo estendido. 
# Aínda que é unha soa función, metémola nun RooAddPdf para que MINUIT calcule o nbkg_fail
model_fail = ROOT.RooAddPdf("model_fail", "Background Only Fail", [bkg_fail], [nbkg_fail])

# 6. Lanzamos o fit (supoñendo que a túa variable de datos se chama roo_data_fail)
model_fail.fitTo(roo_data_fail)
# Out:
# <cppyy.gbl.RooFitResult object at 0x(nil)>
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (bkg_fail)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 nbkg_fail    1.00000e+03  5.00000e+02    0.00000e+00  5.00000e+04
#      2 tau_fail    -1.00000e-03  5.00000e-04   -2.00000e-02  0.00000e+00
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        1000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-4168.78 FROM MIGRAD    STATUS=INITIATE        8 CALLS           9 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  nbkg_fail    1.00000e+03   5.00000e+02   7.39156e-02  -6.13690e+04
#    2  tau_fail    -1.00000e-03   5.00000e-04   1.18625e-01   1.49697e+02
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-17662.9 FROM MIGRAD    STATUS=CONVERGED      46 CALLS          47 TOTAL
#                      EDM=3.30247e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  nbkg_fail    9.76753e+03   9.88321e+01   4.57650e-04   1.08059e+00
#    2  tau_fail    -1.11971e-03   5.90751e-05   1.18812e-03  -1.55669e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   9.768e+03  0.000e+00
#   0.000e+00  3.490e-09
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.00000   1.000  0.000
#         2  0.00000   0.000  1.000
#  **********
#  **    7 **SET ERR         0.5
#  **********
#  **********
#  **    8 **SET PRINT           1
#  **********
#  **********
#  **    9 **HESSE        1000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-17662.9 FROM HESSE     STATUS=OK             10 CALLS          57 TOTAL
#                      EDM=3.3014e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  nbkg_fail    9.76753e+03   9.88321e+01   9.15299e-05  -6.55176e-01
#    2  tau_fail    -1.11971e-03   5.90751e-05   2.37625e-04   1.09304e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   9.768e+03  0.000e+00
#   0.000e+00  3.490e-09
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.00000   1.000  0.000
#         2  0.00000   0.000  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %% [markdown]
# Ploteamos agora os datos xunto cos fits

# %%
# Creamos o frame
frame_all = mass.frame(ROOT.RooFit.Title("Comparacion Tag vs Match vs Fail"))

# 1. TAG (Datos e modelo en NEGRO por defecto)
roo_data_tag.plotOn(frame_all, ROOT.RooFit.Name("DataTag")) 
model_tag.plotOn(frame_all, ROOT.RooFit.Name("ModelTag"))

# 2. MATCH (Datos e modelo en VERMELLO continuo)
roo_data_match.plotOn(frame_all, 
                      ROOT.RooFit.Name("DataMatch"), 
                      ROOT.RooFit.MarkerColor(ROOT.kBlack), 
                      ROOT.RooFit.LineColor(ROOT.kBlack)) 

model_total.plotOn(frame_all, 
                   ROOT.RooFit.Name("ModelMatch"), 
                   ROOT.RooFit.LineColor(ROOT.kRed)) 

# 3. FAIL (Datos e modelo en VERDE continuo)
roo_data_fail.plotOn(frame_all, 
                      ROOT.RooFit.Name("DataFail"), 
                      ROOT.RooFit.MarkerColor(ROOT.kBlack), 
                      ROOT.RooFit.LineColor(ROOT.kBlack))

model_fail.plotOn(frame_all, 
                   ROOT.RooFit.Name("ModelFail"), 
                   ROOT.RooFit.LineColor(ROOT.kGreen))

# Debuxamos
c_final = ROOT.TCanvas("c_final", "Canvas Final", 800, 600)
leg = ROOT.TLegend(0.80, 0.65, 0.90, 0.88)
leg.SetBorderSize(0)      # Quítalle o bordo negro á caixa para que quede máis pro
leg.SetFillStyle(0)       # Fai que o fondo da lenda sexa transparente
leg.SetTextSize(0.035)    # Tamaño da letra

# Engadimos os modelos usando os nomes exactos. 
# O "L" significa que queremos que na lenda se debuxe unha Liña.
leg.AddEntry(frame_all.findObject("ModelTag"), "Tag", "L")
leg.AddEntry(frame_all.findObject("ModelMatch"), "Match", "L")
leg.AddEntry(frame_all.findObject("ModelFail"), "Fail", "L")


ROOT.gROOT.ProcessLine(".L lhcbStyle.C")
ROOT.lhcbStyle()
frame_all.Draw()
leg.Draw("SAME")
c_final.Draw()
title_text = ROOT.TLatex()
title_text.SetNDC()              
title_text.SetTextSize(0.045)    
title_text.SetTextFont(62)       # Tipo de letra (62 adoita ser negrita en ROOT)
title_text.SetTextAlign(21)      # Aliñación: 2 (centro horizontal), 1 (abaixo vertical)

# Debuxamos o título na posición X=0.5 (centro) e Y=0.92 (arriba do todo)
title_text.DrawLatex(0.5, 0.96, "Axustes Downstream OO")
c_final.SaveAs("Axustes_Down_OO.png")
# Out:
# [#1] INFO:Plotting -- RooPlot::updateFitRangeNorm: New event count of 233713 will supercede previous event count of 243480 for normalization of PDF projections
# [#1] INFO:Plotting -- RooPlot::updateFitRangeNorm: New event count of 9767 will supercede previous event count of 233713 for normalization of PDF projections
# -------------------------
# Set LHCb Style - May 2021
# -------------------------
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c_final
# Info in <TCanvas::Print>: png file Axustes_Down_OO.png has been created
