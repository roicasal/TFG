# %%
import ROOT
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ROOT.EnableImplicitMT(10)
# Out:
# Welcome to JupyROOT 6.28/04

# %% [markdown]
# Neste ficheiro vaise realizar un fit ao montecarlo para entender o comportamento do pico de masa dos samples tag e match para as trazas Downstream de OO, de forma que os resultados obtidos serán usados despois nos datos como parámetros iniciais do fit ou incluso algúns como parámetros fixados

# %% [markdown]
# Comezamos entón por ler os datos de MC

# %%
pathmc = '/rxc_lustre/ivan.cambon/TrackCalibmu_AA_tuples/MC/OO_2025/trackeffmu_OO_mc_2025.root'


tdf_mc = ROOT.RDataFrame("charmonium_mu_mu_Down_mup_Tag/DecayTree", pathmc)

# %% [markdown]
# Aplicamos os mesmos filtros que en data:

# %%
datamc = tdf_mc.Filter("dimuon_BPVIP < 0.35 && dimuon_DOCA_12 < 0.5 &&  dimuon_PT > 2000 && mum_CHI2DOF < 1.5 && mum_P > 1000 && mum_PID_MU > 0 && mum_PT > 1500 && mup_CHI2DOF < 1.2")
datamc = datamc.Filter("abs(dimuon_TRUEID)==443")

# %% [markdown]
# Definimos a variable sobre a que facer os fits (masa) e a continuación realízase o fit a unha Gaussiana + CB

# %%
mass = ROOT.RooRealVar("dimuon_M", "m(#mu#mu)", 3000, 3200) 
data = datamc.AsNumpy(["dimuon_M"])
roo_data = ROOT.RooDataSet.from_numpy(
    {"dimuon_M": data["dimuon_M"]},
    [mass]
)
# Out:
# [#0] WARNING:DataHandling -- RooDataSet.from_numpy() Ignored 214 out-of-range events

# %%
# 1. Variables do sinal
mean   = ROOT.RooRealVar("mean", "mean", 3096, 3070, 3130)
sigma1 = ROOT.RooRealVar("sigma1", "sigma gauss", 8, 2, 15)  # O núcleo estreito
sigma2 = ROOT.RooRealVar("sigma2", "sigma cb", 25, 15, 80)   # As colas
alpha  = ROOT.RooRealVar("alpha", "alpha", 1.5, 0.1, 10)
n      = ROOT.RooRealVar("n", "n", 3, -5, 50)               # Protexemos n para que non colapse

# 2. Funcións do sinal
gauss = ROOT.RooGaussian("gauss", "Gaussian Core", mass, mean, sigma1)
cb    = ROOT.RooCBShape("cb", "Crystal Ball Tail", mass, mean, sigma2, alpha, n)

sig_frac = ROOT.RooRealVar("sig_frac", "fraction Gauss/CB", 0.5, 0, 1)

# Creamos o pdf do sinal combinado
signal = ROOT.RooAddPdf("signal", "Gauss + CB", [gauss, cb], [sig_frac])
# FIteamos
signal.fitTo(roo_data)
# Out:
# <cppyy.gbl.RooFitResult object at 0x(nil)>
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (gauss,cb)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha        1.50000e+00  7.00000e-01    1.00000e-01  1.00000e+01
#      2 mean         3.09600e+03  6.00000e+00    3.07000e+03  3.13000e+03
#      3 n            3.00000e+00  4.00000e+00   -5.00000e+00  5.00000e+01
#      4 sig_frac     5.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      5 sigma1       8.00000e+00  1.30000e+00    2.00000e+00  1.50000e+01
#      6 sigma2       2.50000e+01  5.00000e+00    1.50000e+01  8.00000e+01
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        3000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=38071.7 FROM MIGRAD    STATUS=INITIATE       24 CALLS          25 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        1.50000e+00   7.00000e-01   2.09487e-01  -4.68694e+02
#    2  mean         3.09600e+03   6.00000e+00   2.03277e-01  -2.33456e+03
#    3  n            3.00000e+00   4.00000e+00   2.12947e-01  -1.52502e+02
#    4  sig_frac     5.00000e-01   1.00000e-01   2.01358e-01   6.33810e+02
#    5  sigma1       8.00000e+00   1.30000e+00   2.01990e-01  -8.53522e+02
#    6  sigma2       2.50000e+01   5.00000e+00   2.20058e-01   1.52605e+02
#                                ERR DEF= 0.5
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (38122.4) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=2.23037	mean=3098.09	n=-0.877037	sig_frac=0.656094	sigma1=13.5988	sigma2=26.0876
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3033.34, m0=mean=3098.09, sigma=sigma2=26.0876, alpha=alpha=2.23037, n=n=-0.877037
#      p.d.f value is Not-a-Number @ m=dimuon_M=3026.33, m0=mean=3098.09, sigma=sigma2=26.0876, alpha=alpha=2.23037, n=n=-0.877037
#      p.d.f value is Not-a-Number @ m=dimuon_M=3003.16, m0=mean=3098.09, sigma=sigma2=26.0876, alpha=alpha=2.23037, n=n=-0.877037
#      p.d.f value is Not-a-Number @ m=dimuon_M=3034.43, m0=mean=3098.09, sigma=sigma2=26.0876, alpha=alpha=2.23037, n=n=-0.877037
#      p.d.f value is Not-a-Number @ m=dimuon_M=3017.89, m0=mean=3098.09, sigma=sigma2=26.0876, alpha=alpha=2.23037, n=n=-0.877037
#      p.d.f value is Not-a-Number @ m=dimuon_M=3033.16, m0=mean=3098.09, sigma=sigma2=26.0876, alpha=alpha=2.23037, n=n=-0.877037
#      p.d.f value is Not-a-Number @ m=dimuon_M=3038.08, m0=mean=3098.09, sigma=sigma2=26.0876, alpha=alpha=2.23037, n=n=-0.877037
#      p.d.f value is Not-a-Number @ m=dimuon_M=3031.12, m0=mean=3098.09, sigma=sigma2=26.0876, alpha=alpha=2.23037, n=n=-0.877037
#      p.d.f value is Not-a-Number @ m=dimuon_M=3014.66, m0=mean=3098.09, sigma=sigma2=26.0876, alpha=alpha=2.23037, n=n=-0.877037
#      p.d.f value is Not-a-Number @ m=dimuon_M=3030.93, m0=mean=3098.09, sigma=sigma2=26.0876, alpha=alpha=2.23037, n=n=-0.877037
#      p.d.f value is Not-a-Number @ m=dimuon_M=3028.77, m0=mean=3098.09, sigma=sigma2=26.0876, alpha=alpha=2.23037, n=n=-0.877037
#      p.d.f value is Not-a-Number @ m=dimuon_M=3038.55, m0=mean=3098.09, sigma=sigma2=26.0876, alpha=alpha=2.23037, n=n=-0.877037
#     ... (remaining 110 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00328849/34.0872,cb = -nan/-nan), !coefficients=(sig_frac = 0.656094)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0254401/34.0872,cb = -nan/-nan), !coefficients=(sig_frac = 0.656094)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.029096/34.0872,cb = -nan/-nan), !coefficients=(sig_frac = 0.656094)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0268879/34.0872,cb = -nan/-nan), !coefficients=(sig_frac = 0.656094)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0195459/34.0872,cb = -nan/-nan), !coefficients=(sig_frac = 0.656094)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0107571/34.0872,cb = -nan/-nan), !coefficients=(sig_frac = 0.656094)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 1.96113e-05/34.0872,cb = -nan/-nan), !coefficients=(sig_frac = 0.656094)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00032921/34.0872,cb = -nan/-nan), !coefficients=(sig_frac = 0.656094)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0285286/34.0872,cb = -nan/-nan), !coefficients=(sig_frac = 0.656094)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 9.63416e-05/34.0872,cb = -nan/-nan), !coefficients=(sig_frac = 0.656094)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0249365/34.0872,cb = -nan/-nan), !coefficients=(sig_frac = 0.656094)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0290873/34.0872,cb = -nan/-nan), !coefficients=(sig_frac = 0.656094)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 2.23037,mean = 3098.09,n = -0.877037,sig_frac = 0.656094,sigma1 = 13.5988,sigma2 = 26.0876)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3079.72), !jacList=(), !facList=(), !func=cb=0.780423/61.655, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (38122.4) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=2.14532	mean=3098.17	n=-0.389945	sig_frac=0.625197	sigma1=13.3108	sigma2=25.4584
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3033.34, m0=mean=3098.17, sigma=sigma2=25.4584, alpha=alpha=2.14532, n=n=-0.389945
#      p.d.f value is Not-a-Number @ m=dimuon_M=3042.39, m0=mean=3098.17, sigma=sigma2=25.4584, alpha=alpha=2.14532, n=n=-0.389945
#      p.d.f value is Not-a-Number @ m=dimuon_M=3026.33, m0=mean=3098.17, sigma=sigma2=25.4584, alpha=alpha=2.14532, n=n=-0.389945
#      p.d.f value is Not-a-Number @ m=dimuon_M=3003.16, m0=mean=3098.17, sigma=sigma2=25.4584, alpha=alpha=2.14532, n=n=-0.389945
#      p.d.f value is Not-a-Number @ m=dimuon_M=3040.02, m0=mean=3098.17, sigma=sigma2=25.4584, alpha=alpha=2.14532, n=n=-0.389945
#      p.d.f value is Not-a-Number @ m=dimuon_M=3040.38, m0=mean=3098.17, sigma=sigma2=25.4584, alpha=alpha=2.14532, n=n=-0.389945
#      p.d.f value is Not-a-Number @ m=dimuon_M=3034.43, m0=mean=3098.17, sigma=sigma2=25.4584, alpha=alpha=2.14532, n=n=-0.389945
#      p.d.f value is Not-a-Number @ m=dimuon_M=3017.89, m0=mean=3098.17, sigma=sigma2=25.4584, alpha=alpha=2.14532, n=n=-0.389945
#      p.d.f value is Not-a-Number @ m=dimuon_M=3033.16, m0=mean=3098.17, sigma=sigma2=25.4584, alpha=alpha=2.14532, n=n=-0.389945
#      p.d.f value is Not-a-Number @ m=dimuon_M=3038.08, m0=mean=3098.17, sigma=sigma2=25.4584, alpha=alpha=2.14532, n=n=-0.389945
#      p.d.f value is Not-a-Number @ m=dimuon_M=3042.7, m0=mean=3098.17, sigma=sigma2=25.4584, alpha=alpha=2.14532, n=n=-0.389945
#      p.d.f value is Not-a-Number @ m=dimuon_M=3031.12, m0=mean=3098.17, sigma=sigma2=25.4584, alpha=alpha=2.14532, n=n=-0.389945
#     ... (remaining 129 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00301133/33.3651,cb = -nan/-nan), !coefficients=(sig_frac = 0.625197)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0257385/33.3651,cb = -nan/-nan), !coefficients=(sig_frac = 0.625197)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0297394/33.3651,cb = -nan/-nan), !coefficients=(sig_frac = 0.625197)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0274396/33.3651,cb = -nan/-nan), !coefficients=(sig_frac = 0.625197)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0195015/33.3651,cb = -nan/-nan), !coefficients=(sig_frac = 0.625197)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0106157/33.3651,cb = -nan/-nan), !coefficients=(sig_frac = 0.625197)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 1.49195e-05/33.3651,cb = -nan/-nan), !coefficients=(sig_frac = 0.625197)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.000270977/33.3651,cb = -nan/-nan), !coefficients=(sig_frac = 0.625197)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0290648/33.3651,cb = -nan/-nan), !coefficients=(sig_frac = 0.625197)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 7.49599e-05/33.3651,cb = -nan/-nan), !coefficients=(sig_frac = 0.625197)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0253897/33.3651,cb = -nan/-nan), !coefficients=(sig_frac = 0.625197)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0296797/33.3651,cb = -nan/-nan), !coefficients=(sig_frac = 0.625197)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 2.14532,mean = 3098.17,n = -0.389945,sig_frac = 0.625197,sigma1 = 13.3108,sigma2 = 25.4584)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3079.72), !jacList=(), !facList=(), !func=cb=0.768935/60.6956, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (38122.4) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=2.42911	mean=3097.95	n=-0.828841	sig_frac=0.761291	sigma1=13.7639	sigma2=29.3533
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3026.33, m0=mean=3097.95, sigma=sigma2=29.3533, alpha=alpha=2.42911, n=n=-0.828841
#      p.d.f value is Not-a-Number @ m=dimuon_M=3003.16, m0=mean=3097.95, sigma=sigma2=29.3533, alpha=alpha=2.42911, n=n=-0.828841
#      p.d.f value is Not-a-Number @ m=dimuon_M=3017.89, m0=mean=3097.95, sigma=sigma2=29.3533, alpha=alpha=2.42911, n=n=-0.828841
#      p.d.f value is Not-a-Number @ m=dimuon_M=3014.66, m0=mean=3097.95, sigma=sigma2=29.3533, alpha=alpha=2.42911, n=n=-0.828841
#      p.d.f value is Not-a-Number @ m=dimuon_M=3005.16, m0=mean=3097.95, sigma=sigma2=29.3533, alpha=alpha=2.42911, n=n=-0.828841
#      p.d.f value is Not-a-Number @ m=dimuon_M=3002.18, m0=mean=3097.95, sigma=sigma2=29.3533, alpha=alpha=2.42911, n=n=-0.828841
#      p.d.f value is Not-a-Number @ m=dimuon_M=3009.36, m0=mean=3097.95, sigma=sigma2=29.3533, alpha=alpha=2.42911, n=n=-0.828841
#      p.d.f value is Not-a-Number @ m=dimuon_M=3017.72, m0=mean=3097.95, sigma=sigma2=29.3533, alpha=alpha=2.42911, n=n=-0.828841
#      p.d.f value is Not-a-Number @ m=dimuon_M=3021.72, m0=mean=3097.95, sigma=sigma2=29.3533, alpha=alpha=2.42911, n=n=-0.828841
#      p.d.f value is Not-a-Number @ m=dimuon_M=3008.28, m0=mean=3097.95, sigma=sigma2=29.3533, alpha=alpha=2.42911, n=n=-0.828841
#      p.d.f value is Not-a-Number @ m=dimuon_M=3012.24, m0=mean=3097.95, sigma=sigma2=29.3533, alpha=alpha=2.42911, n=n=-0.828841
#      p.d.f value is Not-a-Number @ m=dimuon_M=3023.4, m0=mean=3097.95, sigma=sigma2=29.3533, alpha=alpha=2.42911, n=n=-0.828841
#     ... (remaining 59 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00349232/34.501,cb = -nan/-nan), !coefficients=(sig_frac = 0.761291)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0253489/34.501,cb = -nan/-nan), !coefficients=(sig_frac = 0.761291)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.028716/34.501,cb = -nan/-nan), !coefficients=(sig_frac = 0.761291)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0265131/34.501,cb = -nan/-nan), !coefficients=(sig_frac = 0.761291)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0196678/34.501,cb = -nan/-nan), !coefficients=(sig_frac = 0.761291)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.010738/34.501,cb = -nan/-nan), !coefficients=(sig_frac = 0.761291)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 2.22338e-05/34.501,cb = -nan/-nan), !coefficients=(sig_frac = 0.761291)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.000372556/34.501,cb = -nan/-nan), !coefficients=(sig_frac = 0.761291)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0282679/34.501,cb = -nan/-nan), !coefficients=(sig_frac = 0.761291)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.000112684/34.501,cb = -nan/-nan), !coefficients=(sig_frac = 0.761291)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.024597/34.501,cb = -nan/-nan), !coefficients=(sig_frac = 0.761291)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.028779/34.501,cb = -nan/-nan), !coefficients=(sig_frac = 0.761291)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 2.42911,mean = 3097.95,n = -0.828841,sig_frac = 0.761291,sigma1 = 13.7639,sigma2 = 29.3533)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3079.72), !jacList=(), !facList=(), !func=cb=0.824494/67.9834, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (38122.4) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=2.4409	mean=3098.07	n=-0.690279	sig_frac=0.760431	sigma1=13.7775	sigma2=29.5492
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3003.16, m0=mean=3098.07, sigma=sigma2=29.5492, alpha=alpha=2.4409, n=n=-0.690279
#      p.d.f value is Not-a-Number @ m=dimuon_M=3017.89, m0=mean=3098.07, sigma=sigma2=29.5492, alpha=alpha=2.4409, n=n=-0.690279
#      p.d.f value is Not-a-Number @ m=dimuon_M=3014.66, m0=mean=3098.07, sigma=sigma2=29.5492, alpha=alpha=2.4409, n=n=-0.690279
#      p.d.f value is Not-a-Number @ m=dimuon_M=3005.16, m0=mean=3098.07, sigma=sigma2=29.5492, alpha=alpha=2.4409, n=n=-0.690279
#      p.d.f value is Not-a-Number @ m=dimuon_M=3002.18, m0=mean=3098.07, sigma=sigma2=29.5492, alpha=alpha=2.4409, n=n=-0.690279
#      p.d.f value is Not-a-Number @ m=dimuon_M=3009.36, m0=mean=3098.07, sigma=sigma2=29.5492, alpha=alpha=2.4409, n=n=-0.690279
#      p.d.f value is Not-a-Number @ m=dimuon_M=3017.72, m0=mean=3098.07, sigma=sigma2=29.5492, alpha=alpha=2.4409, n=n=-0.690279
#      p.d.f value is Not-a-Number @ m=dimuon_M=3021.72, m0=mean=3098.07, sigma=sigma2=29.5492, alpha=alpha=2.4409, n=n=-0.690279
#      p.d.f value is Not-a-Number @ m=dimuon_M=3008.28, m0=mean=3098.07, sigma=sigma2=29.5492, alpha=alpha=2.4409, n=n=-0.690279
#      p.d.f value is Not-a-Number @ m=dimuon_M=3012.24, m0=mean=3098.07, sigma=sigma2=29.5492, alpha=alpha=2.4409, n=n=-0.690279
#      p.d.f value is Not-a-Number @ m=dimuon_M=3023.4, m0=mean=3098.07, sigma=sigma2=29.5492, alpha=alpha=2.4409, n=n=-0.690279
#      p.d.f value is Not-a-Number @ m=dimuon_M=3006.17, m0=mean=3098.07, sigma=sigma2=29.5492, alpha=alpha=2.4409, n=n=-0.690279
#     ... (remaining 56 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00344215/34.535,cb = -nan/-nan), !coefficients=(sig_frac = 0.760431)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0252177/34.535,cb = -nan/-nan), !coefficients=(sig_frac = 0.760431)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0287208/34.535,cb = -nan/-nan), !coefficients=(sig_frac = 0.760431)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0265866/34.535,cb = -nan/-nan), !coefficients=(sig_frac = 0.760431)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.019515/34.535,cb = -nan/-nan), !coefficients=(sig_frac = 0.760431)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0108784/34.535,cb = -nan/-nan), !coefficients=(sig_frac = 0.760431)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 2.32687e-05/34.535,cb = -nan/-nan), !coefficients=(sig_frac = 0.760431)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.000366012/34.535,cb = -nan/-nan), !coefficients=(sig_frac = 0.760431)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0281864/34.535,cb = -nan/-nan), !coefficients=(sig_frac = 0.760431)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.000110604/34.535,cb = -nan/-nan), !coefficients=(sig_frac = 0.760431)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0247007/34.535,cb = -nan/-nan), !coefficients=(sig_frac = 0.760431)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0287207/34.535,cb = -nan/-nan), !coefficients=(sig_frac = 0.760431)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 2.4409,mean = 3098.07,n = -0.690279,sig_frac = 0.760431,sigma1 = 13.7775,sigma2 = 29.5492)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3079.72), !jacList=(), !facList=(), !func=cb=0.824558/68.3637, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (38122.4) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=2.45574	mean=3098.1	n=-0.657028	sig_frac=0.766719	sigma1=13.8045	sigma2=29.8889
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3003.16, m0=mean=3098.1, sigma=sigma2=29.8889, alpha=alpha=2.45574, n=n=-0.657028
#      p.d.f value is Not-a-Number @ m=dimuon_M=3017.89, m0=mean=3098.1, sigma=sigma2=29.8889, alpha=alpha=2.45574, n=n=-0.657028
#      p.d.f value is Not-a-Number @ m=dimuon_M=3014.66, m0=mean=3098.1, sigma=sigma2=29.8889, alpha=alpha=2.45574, n=n=-0.657028
#      p.d.f value is Not-a-Number @ m=dimuon_M=3005.16, m0=mean=3098.1, sigma=sigma2=29.8889, alpha=alpha=2.45574, n=n=-0.657028
#      p.d.f value is Not-a-Number @ m=dimuon_M=3002.18, m0=mean=3098.1, sigma=sigma2=29.8889, alpha=alpha=2.45574, n=n=-0.657028
#      p.d.f value is Not-a-Number @ m=dimuon_M=3009.36, m0=mean=3098.1, sigma=sigma2=29.8889, alpha=alpha=2.45574, n=n=-0.657028
#      p.d.f value is Not-a-Number @ m=dimuon_M=3017.72, m0=mean=3098.1, sigma=sigma2=29.8889, alpha=alpha=2.45574, n=n=-0.657028
#      p.d.f value is Not-a-Number @ m=dimuon_M=3021.72, m0=mean=3098.1, sigma=sigma2=29.8889, alpha=alpha=2.45574, n=n=-0.657028
#      p.d.f value is Not-a-Number @ m=dimuon_M=3008.28, m0=mean=3098.1, sigma=sigma2=29.8889, alpha=alpha=2.45574, n=n=-0.657028
#      p.d.f value is Not-a-Number @ m=dimuon_M=3012.24, m0=mean=3098.1, sigma=sigma2=29.8889, alpha=alpha=2.45574, n=n=-0.657028
#      p.d.f value is Not-a-Number @ m=dimuon_M=3023.4, m0=mean=3098.1, sigma=sigma2=29.8889, alpha=alpha=2.45574, n=n=-0.657028
#      p.d.f value is Not-a-Number @ m=dimuon_M=3006.17, m0=mean=3098.1, sigma=sigma2=29.8889, alpha=alpha=2.45574, n=n=-0.657028
#     ... (remaining 54 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00344637/34.6027,cb = -nan/-nan), !coefficients=(sig_frac = 0.766719)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0251488/34.6027,cb = -nan/-nan), !coefficients=(sig_frac = 0.766719)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0286745/34.6027,cb = -nan/-nan), !coefficients=(sig_frac = 0.766719)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0265706/34.6027,cb = -nan/-nan), !coefficients=(sig_frac = 0.766719)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0194637/34.6027,cb = -nan/-nan), !coefficients=(sig_frac = 0.766719)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0109368/34.6027,cb = -nan/-nan), !coefficients=(sig_frac = 0.766719)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 2.41055e-05/34.6027,cb = -nan/-nan), !coefficients=(sig_frac = 0.766719)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.000368866/34.6027,cb = -nan/-nan), !coefficients=(sig_frac = 0.766719)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0281178/34.6027,cb = -nan/-nan), !coefficients=(sig_frac = 0.766719)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.000111883/34.6027,cb = -nan/-nan), !coefficients=(sig_frac = 0.766719)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0247023/34.6027,cb = -nan/-nan), !coefficients=(sig_frac = 0.766719)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0286561/34.6027,cb = -nan/-nan), !coefficients=(sig_frac = 0.766719)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 2.45574,mean = 3098.1,n = -0.657028,sig_frac = 0.766719,sigma1 = 13.8045,sigma2 = 29.8889)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3079.72), !jacList=(), !facList=(), !func=cb=0.827574/68.7557, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (38122.4) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=2.30163	mean=3098.18	n=-0.187185	sig_frac=0.717934	sigma1=13.4717	sigma2=28.4475
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3026.33, m0=mean=3098.18, sigma=sigma2=28.4475, alpha=alpha=2.30163, n=n=-0.187185
#      p.d.f value is Not-a-Number @ m=dimuon_M=3003.16, m0=mean=3098.18, sigma=sigma2=28.4475, alpha=alpha=2.30163, n=n=-0.187185
#      p.d.f value is Not-a-Number @ m=dimuon_M=3017.89, m0=mean=3098.18, sigma=sigma2=28.4475, alpha=alpha=2.30163, n=n=-0.187185
#      p.d.f value is Not-a-Number @ m=dimuon_M=3031.12, m0=mean=3098.18, sigma=sigma2=28.4475, alpha=alpha=2.30163, n=n=-0.187185
#      p.d.f value is Not-a-Number @ m=dimuon_M=3014.66, m0=mean=3098.18, sigma=sigma2=28.4475, alpha=alpha=2.30163, n=n=-0.187185
#      p.d.f value is Not-a-Number @ m=dimuon_M=3030.93, m0=mean=3098.18, sigma=sigma2=28.4475, alpha=alpha=2.30163, n=n=-0.187185
#      p.d.f value is Not-a-Number @ m=dimuon_M=3028.77, m0=mean=3098.18, sigma=sigma2=28.4475, alpha=alpha=2.30163, n=n=-0.187185
#      p.d.f value is Not-a-Number @ m=dimuon_M=3029.21, m0=mean=3098.18, sigma=sigma2=28.4475, alpha=alpha=2.30163, n=n=-0.187185
#      p.d.f value is Not-a-Number @ m=dimuon_M=3005.16, m0=mean=3098.18, sigma=sigma2=28.4475, alpha=alpha=2.30163, n=n=-0.187185
#      p.d.f value is Not-a-Number @ m=dimuon_M=3002.18, m0=mean=3098.18, sigma=sigma2=28.4475, alpha=alpha=2.30163, n=n=-0.187185
#      p.d.f value is Not-a-Number @ m=dimuon_M=3009.36, m0=mean=3098.18, sigma=sigma2=28.4475, alpha=alpha=2.30163, n=n=-0.187185
#      p.d.f value is Not-a-Number @ m=dimuon_M=3017.72, m0=mean=3098.18, sigma=sigma2=28.4475, alpha=alpha=2.30163, n=n=-0.187185
#     ... (remaining 80 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00313923/33.7685,cb = -nan/-nan), !coefficients=(sig_frac = 0.717934)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0255169/33.7685,cb = -nan/-nan), !coefficients=(sig_frac = 0.717934)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0293912/33.7685,cb = -nan/-nan), !coefficients=(sig_frac = 0.717934)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0271738/33.7685,cb = -nan/-nan), !coefficients=(sig_frac = 0.717934)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0194582/33.7685,cb = -nan/-nan), !coefficients=(sig_frac = 0.717934)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0107575/33.7685,cb = -nan/-nan), !coefficients=(sig_frac = 0.717934)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 1.769e-05/33.7685,cb = -nan/-nan), !coefficients=(sig_frac = 0.717934)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.000298988/33.7685,cb = -nan/-nan), !coefficients=(sig_frac = 0.717934)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0287354/33.7685,cb = -nan/-nan), !coefficients=(sig_frac = 0.717934)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 8.52565e-05/33.7685,cb = -nan/-nan), !coefficients=(sig_frac = 0.717934)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0251919/33.7685,cb = -nan/-nan), !coefficients=(sig_frac = 0.717934)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0293302/33.7685,cb = -nan/-nan), !coefficients=(sig_frac = 0.717934)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 2.30163,mean = 3098.18,n = -0.187185,sig_frac = 0.717934,sigma1 = 13.4717,sigma2 = 28.4475)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3079.72), !jacList=(), !facList=(), !func=cb=0.810122/69.1843, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (38122.4) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=2.26696	mean=3098.23	n=-0.0880337	sig_frac=0.711179	sigma1=13.4159	sigma2=28.3106
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3033.34, m0=mean=3098.23, sigma=sigma2=28.3106, alpha=alpha=2.26696, n=n=-0.0880337
#      p.d.f value is Not-a-Number @ m=dimuon_M=3026.33, m0=mean=3098.23, sigma=sigma2=28.3106, alpha=alpha=2.26696, n=n=-0.0880337
#      p.d.f value is Not-a-Number @ m=dimuon_M=3003.16, m0=mean=3098.23, sigma=sigma2=28.3106, alpha=alpha=2.26696, n=n=-0.0880337
#      p.d.f value is Not-a-Number @ m=dimuon_M=3017.89, m0=mean=3098.23, sigma=sigma2=28.3106, alpha=alpha=2.26696, n=n=-0.0880337
#      p.d.f value is Not-a-Number @ m=dimuon_M=3033.16, m0=mean=3098.23, sigma=sigma2=28.3106, alpha=alpha=2.26696, n=n=-0.0880337
#      p.d.f value is Not-a-Number @ m=dimuon_M=3031.12, m0=mean=3098.23, sigma=sigma2=28.3106, alpha=alpha=2.26696, n=n=-0.0880337
#      p.d.f value is Not-a-Number @ m=dimuon_M=3014.66, m0=mean=3098.23, sigma=sigma2=28.3106, alpha=alpha=2.26696, n=n=-0.0880337
#      p.d.f value is Not-a-Number @ m=dimuon_M=3030.93, m0=mean=3098.23, sigma=sigma2=28.3106, alpha=alpha=2.26696, n=n=-0.0880337
#      p.d.f value is Not-a-Number @ m=dimuon_M=3028.77, m0=mean=3098.23, sigma=sigma2=28.3106, alpha=alpha=2.26696, n=n=-0.0880337
#      p.d.f value is Not-a-Number @ m=dimuon_M=3029.21, m0=mean=3098.23, sigma=sigma2=28.3106, alpha=alpha=2.26696, n=n=-0.0880337
#      p.d.f value is Not-a-Number @ m=dimuon_M=3005.16, m0=mean=3098.23, sigma=sigma2=28.3106, alpha=alpha=2.26696, n=n=-0.0880337
#      p.d.f value is Not-a-Number @ m=dimuon_M=3002.18, m0=mean=3098.23, sigma=sigma2=28.3106, alpha=alpha=2.26696, n=n=-0.0880337
#     ... (remaining 83 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00307052/33.6286,cb = -nan/-nan), !coefficients=(sig_frac = 0.711179)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0255413/33.6286,cb = -nan/-nan), !coefficients=(sig_frac = 0.711179)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0295244/33.6286,cb = -nan/-nan), !coefficients=(sig_frac = 0.711179)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0273075/33.6286,cb = -nan/-nan), !coefficients=(sig_frac = 0.711179)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0194071/33.6286,cb = -nan/-nan), !coefficients=(sig_frac = 0.711179)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.010766/33.6286,cb = -nan/-nan), !coefficients=(sig_frac = 0.711179)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 1.69289e-05/33.6286,cb = -nan/-nan), !coefficients=(sig_frac = 0.711179)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.000285835/33.6286,cb = -nan/-nan), !coefficients=(sig_frac = 0.711179)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0288223/33.6286,cb = -nan/-nan), !coefficients=(sig_frac = 0.711179)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 8.05458e-05/33.6286,cb = -nan/-nan), !coefficients=(sig_frac = 0.711179)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0253138/33.6286,cb = -nan/-nan), !coefficients=(sig_frac = 0.711179)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0294351/33.6286,cb = -nan/-nan), !coefficients=(sig_frac = 0.711179)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 2.26696,mean = 3098.23,n = -0.0880337,sig_frac = 0.711179,sigma1 = 13.4159,sigma2 = 28.3106)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3079.72), !jacList=(), !facList=(), !func=cb=0.80758/69.3844, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (38122.4) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=2.24411	mean=3098.25	n=-0.0295372	sig_frac=0.706583	sigma1=13.3946	sigma2=28.2159
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3033.34, m0=mean=3098.25, sigma=sigma2=28.2159, alpha=alpha=2.24411, n=n=-0.0295372
#      p.d.f value is Not-a-Number @ m=dimuon_M=3026.33, m0=mean=3098.25, sigma=sigma2=28.2159, alpha=alpha=2.24411, n=n=-0.0295372
#      p.d.f value is Not-a-Number @ m=dimuon_M=3003.16, m0=mean=3098.25, sigma=sigma2=28.2159, alpha=alpha=2.24411, n=n=-0.0295372
#      p.d.f value is Not-a-Number @ m=dimuon_M=3034.43, m0=mean=3098.25, sigma=sigma2=28.2159, alpha=alpha=2.24411, n=n=-0.0295372
#      p.d.f value is Not-a-Number @ m=dimuon_M=3017.89, m0=mean=3098.25, sigma=sigma2=28.2159, alpha=alpha=2.24411, n=n=-0.0295372
#      p.d.f value is Not-a-Number @ m=dimuon_M=3033.16, m0=mean=3098.25, sigma=sigma2=28.2159, alpha=alpha=2.24411, n=n=-0.0295372
#      p.d.f value is Not-a-Number @ m=dimuon_M=3031.12, m0=mean=3098.25, sigma=sigma2=28.2159, alpha=alpha=2.24411, n=n=-0.0295372
#      p.d.f value is Not-a-Number @ m=dimuon_M=3014.66, m0=mean=3098.25, sigma=sigma2=28.2159, alpha=alpha=2.24411, n=n=-0.0295372
#      p.d.f value is Not-a-Number @ m=dimuon_M=3030.93, m0=mean=3098.25, sigma=sigma2=28.2159, alpha=alpha=2.24411, n=n=-0.0295372
#      p.d.f value is Not-a-Number @ m=dimuon_M=3028.77, m0=mean=3098.25, sigma=sigma2=28.2159, alpha=alpha=2.24411, n=n=-0.0295372
#      p.d.f value is Not-a-Number @ m=dimuon_M=3029.21, m0=mean=3098.25, sigma=sigma2=28.2159, alpha=alpha=2.24411, n=n=-0.0295372
#      p.d.f value is Not-a-Number @ m=dimuon_M=3005.16, m0=mean=3098.25, sigma=sigma2=28.2159, alpha=alpha=2.24411, n=n=-0.0295372
#     ... (remaining 86 messages suppressed)
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0030408/33.5753,cb = -nan/-nan), !coefficients=(sig_frac = 0.706583)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0255424/33.5753,cb = -nan/-nan), !coefficients=(sig_frac = 0.706583)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0295773/33.5753,cb = -nan/-nan), !coefficients=(sig_frac = 0.706583)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0273651/33.5753,cb = -nan/-nan), !coefficients=(sig_frac = 0.706583)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0193771/33.5753,cb = -nan/-nan), !coefficients=(sig_frac = 0.706583)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0107778/33.5753,cb = -nan/-nan), !coefficients=(sig_frac = 0.706583)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 1.66811e-05/33.5753,cb = -nan/-nan), !coefficients=(sig_frac = 0.706583)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.000280445/33.5753,cb = -nan/-nan), !coefficients=(sig_frac = 0.706583)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0288513/33.5753,cb = -nan/-nan), !coefficients=(sig_frac = 0.706583)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 7.86504e-05/33.5753,cb = -nan/-nan), !coefficients=(sig_frac = 0.706583)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0253687/33.5753,cb = -nan/-nan), !coefficients=(sig_frac = 0.706583)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0294727/33.5753,cb = -nan/-nan), !coefficients=(sig_frac = 0.706583)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 2.24411,mean = 3098.25,n = -0.0295372,sig_frac = 0.706583,sigma1 = 13.3946,sigma2 = 28.2159)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3079.72), !jacList=(), !facList=(), !func=cb=0.805938/69.5515, !sumCat=()
#
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=37749.3 FROM MIGRAD    STATUS=CONVERGED     520 CALLS         521 TOTAL
#                      EDM=2.62048e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        1.76461e+00   2.59505e-01   2.46402e-03   3.02970e-02
#    2  mean         3.09824e+03   1.89620e-01   8.38607e-04   3.44186e-01
#    3  n            6.65934e-01   6.30597e-01   1.41579e-03   5.54613e-02
#    4  sig_frac     7.30654e-01   3.29250e-02   3.08608e-03   3.30179e-02
#    5  sigma1       1.37288e+01   3.56749e-01   6.13721e-03  -4.83128e-02
#    6  sigma2       2.89093e+01   1.30652e+00   3.04984e-03   1.09071e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  6    ERR DEF=0.5
#   6.745e-02 -5.188e-03 -1.511e-01 -3.047e-03 -3.406e-02 -4.570e-02
#  -5.188e-03  3.596e-02  1.295e-02 -2.922e-04 -2.222e-03 -2.386e-02
#  -1.511e-01  1.295e-02  3.978e-01  1.798e-03  2.869e-02 -7.536e-02
#  -3.047e-03 -2.922e-04  1.798e-03  1.086e-03  1.011e-02  3.701e-02
#  -3.406e-02 -2.222e-03  2.869e-02  1.011e-02  1.276e-01  3.137e-01
#  -4.570e-02 -2.386e-02 -7.536e-02  3.701e-02  3.137e-01  1.708e+00
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6
#         1  0.96451   1.000 -0.105 -0.922 -0.356 -0.367 -0.135
#         2  0.16003  -0.105  1.000  0.108 -0.047 -0.033 -0.096
#         3  0.95831  -0.922  0.108  1.000  0.087  0.127 -0.091
#         4  0.95086  -0.356 -0.047  0.087  1.000  0.859  0.859
#         5  0.86910  -0.367 -0.033  0.127  0.859  1.000  0.672
#         6  0.88594  -0.135 -0.096 -0.091  0.859  0.672  1.000
#  **********
#  **    7 **SET ERR         0.5
#  **********
#  **********
#  **    8 **SET PRINT           1
#  **********
#  **********
#  **    9 **HESSE        3000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=37749.3 FROM HESSE     STATUS=OK             40 CALLS         561 TOTAL
#                      EDM=2.67332e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  alpha        1.76461e+00   4.08218e-01   9.85608e-05  -7.25775e-01
#    2  mean         3.09824e+03   1.91357e-01   1.67721e-04  -5.87693e-02
#    3  n            6.65934e-01   1.01599e+00   5.66317e-05  -9.17305e-01
#    4  sig_frac     7.30654e-01   3.40628e-02   1.23443e-04   4.79469e-01
#    5  sigma1       1.37288e+01   3.71495e-01   2.45488e-04   9.34720e-01
#    6  sigma2       2.89093e+01   1.33114e+00   1.21993e-04  -6.08968e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  6    ERR DEF=0.5
#   1.673e-01 -1.324e-02 -4.028e-01 -4.794e-03 -5.871e-02 -1.354e-02
#  -1.324e-02  3.662e-02  3.350e-02 -1.794e-04 -5.454e-04 -2.739e-02
#  -4.028e-01  3.350e-02  1.034e+00  5.910e-03  8.790e-02 -1.672e-01
#  -4.794e-03 -1.794e-04  5.910e-03  1.163e-03  1.101e-02  3.805e-02
#  -5.871e-02 -5.454e-04  8.790e-02  1.101e-02  1.384e-01  3.220e-01
#  -1.354e-02 -2.739e-02 -1.672e-01  3.805e-02  3.220e-01  1.773e+00
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6
#         1  0.98602   1.000 -0.169 -0.969 -0.344 -0.386 -0.025
#         2  0.20790  -0.169  1.000  0.172 -0.027 -0.008 -0.107
#         3  0.98414  -0.969  0.172  1.000  0.171  0.232 -0.123
#         4  0.95417  -0.344 -0.027  0.171  1.000  0.868  0.838
#         5  0.88001  -0.386 -0.008  0.232  0.868  1.000  0.650
#         6  0.89068  -0.025 -0.107 -0.123  0.838  0.650  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %% [markdown]
# Facemos o plot dos resultados para comprobar visualmente

# %%
frame = mass.frame()

roo_data.plotOn(frame)
signal.plotOn(frame)   # ou gauss

c = ROOT.TCanvas()
frame.SetTitle("")
frame.Draw()

title_text = ROOT.TLatex()
title_text.SetNDC()              # Usa coordenadas da pantalla (0 a 1) no canto das dos eixes
title_text.SetTextSize(0.045)    # Tamaño do texto
title_text.SetTextFont(62)       # Tipo de letra (62 adoita ser negrita en ROOT)
title_text.SetTextAlign(21)      # Aliñación: 2 (centro horizontal), 1 (abaixo vertical)

# Debuxamos o título na posición X=0.5 (centro) e Y=0.92 (arriba do todo)
title_text.DrawLatex(0.5, 0.96, "Axustes Downstream OO (MC)")
c.Draw()
