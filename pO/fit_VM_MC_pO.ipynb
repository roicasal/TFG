# %%
import ROOT
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ROOT.EnableImplicitMT(10)
# Out:
# Welcome to JupyROOT 6.28/04

# %%
pathmc = '/rxc_lustre/ivan.cambon/TrackCalibmu_AA_tuples/MC/pO_2025/trackeffmu_pO_mc_2025.root'


tdf_mc = ROOT.RDataFrame("charmonium_mu_mu_VM_mup_Tag/DecayTree", pathmc)

# %%
datamc = tdf_mc.Filter("dimuon_BPVIP < 0.35 && dimuon_DOCA_12 < 0.5 &&  dimuon_PT > 2000 && mum_CHI2DOF < 1.5 && mum_P > 1000 && mum_PID_MU > 0 && mum_PT > 1500 && mup_CHI2DOF < 1.2")
datamc = datamc.Filter("abs(dimuon_TRUEID)==443")

# %%
mass = ROOT.RooRealVar("dimuon_M", "m(#mu#mu)", 2600, 3600) 
data = datamc.AsNumpy(["dimuon_M"])
roo_data = ROOT.RooDataSet.from_numpy(
    {"dimuon_M": data["dimuon_M"]},
    [mass]
)

# %%
# 1. Variables do sinal
mean   = ROOT.RooRealVar("mean", "mean", 3096, 3070, 3130)
sigma1 = ROOT.RooRealVar("sigma1", "sigma gauss", 8, 2, 15)  # O núcleo estreito
sigma2 = ROOT.RooRealVar("sigma2", "sigma cb", 25, 15, 80)   # As colas
alpha  = ROOT.RooRealVar("alpha", "alpha", 1.5, 0.1, 10)
n      = ROOT.RooRealVar("n", "n", 3, 1.5, 50)               # Protexemos n para que non colapse

# 2. Funcións do sinal
gauss = ROOT.RooGaussian("gauss", "Gaussian Core", mass, mean, sigma1)
cb    = ROOT.RooCBShape("cb", "Crystal Ball Tail", mass, mean, sigma2, alpha, n)

sig_frac = ROOT.RooRealVar("sig_frac", "fraction Gauss/CB", 0.5, 0, 1)

# Creamos o pdf do sinal combinado
signal = ROOT.RooAddPdf("signal", "Gauss + CB", [gauss, cb], [sig_frac])

# 3. NOVO: Fondo Exponencial
# tau controla a pendente. Comezamos nun valor lixeiramente negativo (-0.01)
tau = ROOT.RooRealVar("tau", "tau bkg", -0.01, -2.0, 0.5)
bkg = ROOT.RooExponential("bkg", "Exponential Bkg", mass, tau)

# 4. Sumamos SINAL + FONDO usando números de eventos (yields)
# Axusta os valores iniciais (10000 e 2000) se sabes que tes máis ou menos eventos en total
nsig = ROOT.RooRealVar("nsig", "number of signal events", 10000, 0, 100000)
nbkg = ROOT.RooRealVar("nbkg", "number of bkg events", 2000, 0, 100000)

model_total = ROOT.RooAddPdf("model_total", "Signal + Background", [signal, bkg], [nsig, nbkg])

# 5. Fiteamos
model_total.fitTo(roo_data)
# Out:
# <cppyy.gbl.RooFitResult object at 0x(nil)>
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (gauss,cb,bkg)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha        1.50000e+00  7.00000e-01    1.00000e-01  1.00000e+01
#      2 mean         3.09600e+03  6.00000e+00    3.07000e+03  3.13000e+03
#      3 n            3.00000e+00  7.50000e-01    1.50000e+00  5.00000e+01
#      4 nbkg         2.00000e+03  1.00000e+03    0.00000e+00  1.00000e+05
#      5 nsig         1.00000e+04  5.00000e+03    0.00000e+00  1.00000e+05
#      6 sig_frac     5.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      7 sigma1       8.00000e+00  1.30000e+00    2.00000e+00  1.50000e+01
#      8 sigma2       2.50000e+01  5.00000e+00    1.50000e+01  8.00000e+01
#      9 tau         -1.00000e-02  2.50000e-01   -2.00000e+00  5.00000e-01
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        4500           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-146378 FROM MIGRAD    STATUS=INITIATE       64 CALLS          65 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        1.50000e+00   7.00000e-01   0.00000e+00   3.04837e+03
#    2  mean         3.09600e+03   6.00000e+00   0.00000e+00  -9.57201e+03
#    3  n            3.00000e+00   7.50000e-01   0.00000e+00  -8.21221e+02
#    4  nbkg         2.00000e+03   1.00000e+03   0.00000e+00  -3.55158e+04
#    5  nsig         1.00000e+04   5.00000e+03   0.00000e+00  -8.09380e+04
#    6  sig_frac     5.00000e-01   1.00000e-01   0.00000e+00   1.82699e+04
#    7  sigma1       8.00000e+00   1.30000e+00   0.00000e+00  -5.07827e+03
#    8  sigma2       2.50000e+01   5.00000e+00   0.00000e+00  -2.38006e+04
#    9  tau         -3.57942e-04   2.50000e-01   9.60505e-03  -1.43317e+05
#                                ERR DEF= 0.5
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 1 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 2 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 4 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 5 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 6 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 7 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 8 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 9 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== 1.06277 added to diagonal of error matrix
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-127967) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.61218	mean=3091.37	n=6.10586	nbkg=99961.6	nsig=98776.6	sig_frac=0.962419	sigma1=14.3958	sigma2=74.1806	tau=0.230968
# RooNLLVar::nll_model_total_[ parameters=(alpha,mean,n,nbkg,nsig,sig_frac,sigma1,sigma2,tau) ]
#      function value is NAN @ parameters=(alpha = 1.61218,mean = 3091.37,n = 6.10586,nbkg = 99961.6,nsig = 98776.6,sig_frac = 0.962419,sigma1 = 14.3958,sigma2 = 74.1806,tau = 0.230968)
# RooAddPdf::model_total[ nsig * signal + nbkg * bkg ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000599508/1,bkg = -nan/inf), !coefficients=(nsig = 98776.6,nbkg = 99961.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00020098/1,bkg = -nan/inf), !coefficients=(nsig = 98776.6,nbkg = 99961.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0113095/1,bkg = -nan/inf), !coefficients=(nsig = 98776.6,nbkg = 99961.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 9.05876e-05/1,bkg = -nan/inf), !coefficients=(nsig = 98776.6,nbkg = 99961.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000846073/1,bkg = -nan/inf), !coefficients=(nsig = 98776.6,nbkg = 99961.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000443436/1,bkg = -nan/inf), !coefficients=(nsig = 98776.6,nbkg = 99961.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000118461/1,bkg = -nan/inf), !coefficients=(nsig = 98776.6,nbkg = 99961.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0082616/1,bkg = -nan/inf), !coefficients=(nsig = 98776.6,nbkg = 99961.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000139615/1,bkg = -nan/inf), !coefficients=(nsig = 98776.6,nbkg = 99961.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0084199/1,bkg = -nan/inf), !coefficients=(nsig = 98776.6,nbkg = 99961.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00563801/1,bkg = -nan/inf), !coefficients=(nsig = 98776.6,nbkg = 99961.6)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000159981/1,bkg = -nan/inf), !coefficients=(nsig = 98776.6,nbkg = 99961.6)
#     ... (remaining 2038 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (62483.9) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.13129	mean=3070.02	n=1.66937	nbkg=95708.8	nsig=5494.34	sig_frac=0.539311	sigma1=14.8718	sigma2=27.3994	tau=0.488183
# RooNLLVar::nll_model_total_[ parameters=(alpha,mean,n,nbkg,nsig,sig_frac,sigma1,sigma2,tau) ]
#      function value is NAN @ parameters=(alpha = 1.13129,mean = 3070.02,n = 1.66937,nbkg = 95708.8,nsig = 5494.34,sig_frac = 0.539311,sigma1 = 14.8718,sigma2 = 27.3994,tau = 0.488183)
# RooRealIntegral::bkg_Int[dimuon_M][ Int bkgd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3149.99), !jacList=(), !facList=(), !func=bkg=inf/-0, !sumCat=()
# RooAddPdf::model_total[ nsig * signal + nbkg * bkg ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00180445/1,bkg = -nan/-nan), !coefficients=(nsig = 5494.34,nbkg = 95708.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0178374/1,bkg = -nan/-nan), !coefficients=(nsig = 5494.34,nbkg = 95708.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0193734/1,bkg = -nan/-nan), !coefficients=(nsig = 5494.34,nbkg = 95708.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 1.80286e-05/1,bkg = -nan/-nan), !coefficients=(nsig = 5494.34,nbkg = 95708.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000106942/1,bkg = -nan/-nan), !coefficients=(nsig = 5494.34,nbkg = 95708.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00725189/1,bkg = -nan/-nan), !coefficients=(nsig = 5494.34,nbkg = 95708.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00248502/1,bkg = -nan/-nan), !coefficients=(nsig = 5494.34,nbkg = 95708.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00203831/1,bkg = -nan/-nan), !coefficients=(nsig = 5494.34,nbkg = 95708.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0172829/1,bkg = -nan/-nan), !coefficients=(nsig = 5494.34,nbkg = 95708.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0138829/1,bkg = -nan/-nan), !coefficients=(nsig = 5494.34,nbkg = 95708.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0177682/1,bkg = -nan/-nan), !coefficients=(nsig = 5494.34,nbkg = 95708.8)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 3.05909e-05/1,bkg = -nan/-nan), !coefficients=(nsig = 5494.34,nbkg = 95708.8)
#     ... (remaining 2038 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (62483.9) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=8.41689	mean=3121.2	n=4.64786	nbkg=68062.2	nsig=17843.4	sig_frac=0.265707	sigma1=14.8742	sigma2=57.7953	tau=0.485731
# RooNLLVar::nll_model_total_[ parameters=(alpha,mean,n,nbkg,nsig,sig_frac,sigma1,sigma2,tau) ]
#      function value is NAN @ parameters=(alpha = 8.41689,mean = 3121.2,n = 4.64786,nbkg = 68062.2,nsig = 17843.4,sig_frac = 0.265707,sigma1 = 14.8742,sigma2 = 57.7953,tau = 0.485731)
# RooRealIntegral::bkg_Int[dimuon_M][ Int bkgd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3149.99), !jacList=(), !facList=(), !func=bkg=inf/-nan, !sumCat=()
# RooAddPdf::model_total[ nsig * signal + nbkg * bkg ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00123678/1,bkg = -nan/-nan), !coefficients=(nsig = 17843.4,nbkg = 68062.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00391774/1,bkg = -nan/-nan), !coefficients=(nsig = 17843.4,nbkg = 68062.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00365789/1,bkg = -nan/-nan), !coefficients=(nsig = 17843.4,nbkg = 68062.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00407507/1,bkg = -nan/-nan), !coefficients=(nsig = 17843.4,nbkg = 68062.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 4.24933e-10/1,bkg = -nan/-nan), !coefficients=(nsig = 17843.4,nbkg = 68062.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00601656/1,bkg = -nan/-nan), !coefficients=(nsig = 17843.4,nbkg = 68062.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00147946/1,bkg = -nan/-nan), !coefficients=(nsig = 17843.4,nbkg = 68062.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0107058/1,bkg = -nan/-nan), !coefficients=(nsig = 17843.4,nbkg = 68062.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00399369/1,bkg = -nan/-nan), !coefficients=(nsig = 17843.4,nbkg = 68062.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00445435/1,bkg = -nan/-nan), !coefficients=(nsig = 17843.4,nbkg = 68062.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00392743/1,bkg = -nan/-nan), !coefficients=(nsig = 17843.4,nbkg = 68062.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00445896/1,bkg = -nan/-nan), !coefficients=(nsig = 17843.4,nbkg = 68062.2)
#     ... (remaining 2038 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (62483.9) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.15691	mean=3127.5	n=7.41716	nbkg=71310.2	nsig=73895.6	sig_frac=0.151642	sigma1=14.8754	sigma2=15.3677	tau=0.434722
# RooNLLVar::nll_model_total_[ parameters=(alpha,mean,n,nbkg,nsig,sig_frac,sigma1,sigma2,tau) ]
#      function value is NAN @ parameters=(alpha = 1.15691,mean = 3127.5,n = 7.41716,nbkg = 71310.2,nsig = 73895.6,sig_frac = 0.151642,sigma1 = 14.8754,sigma2 = 15.3677,tau = 0.434722)
# RooRealIntegral::bkg_Int[dimuon_M][ Int bkgd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3149.99), !jacList=(), !facList=(), !func=bkg=inf/-nan, !sumCat=()
# RooAddPdf::model_total[ nsig * signal + nbkg * bkg ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000101026/1,bkg = -nan/-nan), !coefficients=(nsig = 73895.6,nbkg = 71310.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00130981/1,bkg = -nan/-nan), !coefficients=(nsig = 73895.6,nbkg = 71310.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00103925/1,bkg = -nan/-nan), !coefficients=(nsig = 73895.6,nbkg = 71310.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0017718/1,bkg = -nan/-nan), !coefficients=(nsig = 73895.6,nbkg = 71310.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 2.35109e-07/1,bkg = -nan/-nan), !coefficients=(nsig = 73895.6,nbkg = 71310.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00399536/1,bkg = -nan/-nan), !coefficients=(nsig = 73895.6,nbkg = 71310.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0001312/1,bkg = -nan/-nan), !coefficients=(nsig = 73895.6,nbkg = 71310.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0139404/1,bkg = -nan/-nan), !coefficients=(nsig = 73895.6,nbkg = 71310.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00139551/1,bkg = -nan/-nan), !coefficients=(nsig = 73895.6,nbkg = 71310.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00195167/1,bkg = -nan/-nan), !coefficients=(nsig = 73895.6,nbkg = 71310.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0013206/1,bkg = -nan/-nan), !coefficients=(nsig = 73895.6,nbkg = 71310.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00328388/1,bkg = -nan/-nan), !coefficients=(nsig = 73895.6,nbkg = 71310.2)
#     ... (remaining 2038 messages suppressed)
#
#  MIGRAD FAILS TO FIND IMPROVEMENT
#  MINUIT WARNING IN HESSE
#  ============== Negative diagonal element 3 in Error Matrix
#  MINUIT WARNING IN HESSE
#  ============== 198.618 added to diagonal of error matrix
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -4.6536e+00  2.7488e-01  5.2333e-01  9.2536e-01  1.0123e+00  1.0249e+00  1.1874e+00  1.5995e+00  7.1060e+00
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 4.660751 TO DIAGONAL.
#  FCN=-192049 FROM HESSE     STATUS=NOT POSDEF     73 CALLS         346 TOTAL
#                      EDM=337659    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        2.02039e+00   1.10798e-01   3.72477e-03   7.96955e+02
#    2  mean         3.10050e+03   2.96041e-01   2.16633e-03  -5.73460e+02
#    3  n            1.07333e+01   2.85840e+01   2.15328e-02   9.50167e+01
#    4  nbkg         1.14559e+03   2.91197e+02   1.14333e-03   1.11809e+03
#    5  nsig         4.18324e+04   2.19480e+02   1.26839e-03  -1.40962e+03
#    6  sig_frac     6.85341e-02   1.91548e-03   6.00303e-03  -1.37256e+02
#    7  sigma1       1.48765e+01   3.35918e-02   3.95172e-02   9.27432e+00
#    8  sigma2       4.56121e+01   5.44118e-01   1.65028e-03   8.34725e+02
#    9  tau         -3.81517e-03   3.69890e-04   5.51719e-05  -5.11275e+04
#                                ERR DEF= 0.5
#  MINUIT WARNING IN MIGRAD
#  ============== Negative diagonal element 3 in Error Matrix
#  MINUIT WARNING IN MIGRAD
#  ============== 1.00831 added to diagonal of error matrix
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (137326) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=0.654234	mean=3127.54	n=3.86989	nbkg=88669.7	nsig=76037.5	sig_frac=0.149522	sigma1=14.898	sigma2=15.863	tau=0.346335
# RooNLLVar::nll_model_total_[ parameters=(alpha,mean,n,nbkg,nsig,sig_frac,sigma1,sigma2,tau) ]
#      function value is NAN @ parameters=(alpha = 0.654234,mean = 3127.54,n = 3.86989,nbkg = 88669.7,nsig = 76037.5,sig_frac = 0.149522,sigma1 = 14.898,sigma2 = 15.863,tau = 0.346335)
# RooRealIntegral::bkg_Int[dimuon_M][ Int bkgd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3149.99), !jacList=(), !facList=(), !func=bkg=inf/-0, !sumCat=()
# RooAddPdf::model_total[ nsig * signal + nbkg * bkg ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000854891/1,bkg = -nan/-nan), !coefficients=(nsig = 76037.5,nbkg = 88669.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00317541/1,bkg = -nan/-nan), !coefficients=(nsig = 76037.5,nbkg = 88669.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00282227/1,bkg = -nan/-nan), !coefficients=(nsig = 76037.5,nbkg = 88669.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00159279/1,bkg = -nan/-nan), !coefficients=(nsig = 76037.5,nbkg = 88669.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 3.73199e-05/1,bkg = -nan/-nan), !coefficients=(nsig = 76037.5,nbkg = 88669.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00570581/1,bkg = -nan/-nan), !coefficients=(nsig = 76037.5,nbkg = 88669.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00097778/1,bkg = -nan/-nan), !coefficients=(nsig = 76037.5,nbkg = 88669.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0119332/1,bkg = -nan/-nan), !coefficients=(nsig = 76037.5,nbkg = 88669.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00327973/1,bkg = -nan/-nan), !coefficients=(nsig = 76037.5,nbkg = 88669.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00389505/1,bkg = -nan/-nan), !coefficients=(nsig = 76037.5,nbkg = 88669.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00318873/1,bkg = -nan/-nan), !coefficients=(nsig = 76037.5,nbkg = 88669.7)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00285993/1,bkg = -nan/-nan), !coefficients=(nsig = 76037.5,nbkg = 88669.7)
#     ... (remaining 2038 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (137326) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=0.270112	mean=3115.75	n=5.53686	nbkg=24406.2	nsig=95111	sig_frac=0.102949	sigma1=14.8868	sigma2=22.5921	tau=0.23311
# RooNLLVar::nll_model_total_[ parameters=(alpha,mean,n,nbkg,nsig,sig_frac,sigma1,sigma2,tau) ]
#      function value is NAN @ parameters=(alpha = 0.270112,mean = 3115.75,n = 5.53686,nbkg = 24406.2,nsig = 95111,sig_frac = 0.102949,sigma1 = 14.8868,sigma2 = 22.5921,tau = 0.23311)
# RooAddPdf::model_total[ nsig * signal + nbkg * bkg ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000813551/1,bkg = -nan/inf), !coefficients=(nsig = 95111,nbkg = 24406.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00413137/1,bkg = -nan/inf), !coefficients=(nsig = 95111,nbkg = 24406.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00440536/1,bkg = -nan/inf), !coefficients=(nsig = 95111,nbkg = 24406.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00673795/1,bkg = -nan/inf), !coefficients=(nsig = 95111,nbkg = 24406.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00853947/1,bkg = -nan/inf), !coefficients=(nsig = 95111,nbkg = 24406.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00497876/1,bkg = -nan/inf), !coefficients=(nsig = 95111,nbkg = 24406.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00375866/1,bkg = -nan/inf), !coefficients=(nsig = 95111,nbkg = 24406.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0070126/1,bkg = -nan/inf), !coefficients=(nsig = 95111,nbkg = 24406.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.0074933/1,bkg = -nan/inf), !coefficients=(nsig = 95111,nbkg = 24406.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.000278638/1,bkg = -nan/inf), !coefficients=(nsig = 95111,nbkg = 24406.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00383939/1,bkg = -nan/inf), !coefficients=(nsig = 95111,nbkg = 24406.2)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(signal = 0.00425822/1,bkg = -nan/inf), !coefficients=(nsig = 95111,nbkg = 24406.2)
#     ... (remaining 2038 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (137326) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.0506	mean=3107.42	n=6.51128	nbkg=2676.7	nsig=69316.2	sig_frac=0.0827226	sigma1=14.8811	sigma2=34.4593	tau=0.326045
# RooNLLVar::nll_model_total_[ parameters=(alpha,mean,n,nbkg,nsig,sig_frac,sigma1,sigma2,tau) ]
#      function value is NAN @ parameters=(alpha = 1.0506,mean = 3107.42,n = 6.51128,nbkg = 2676.7,nsig = 69316.2,sig_frac = 0.0827226,sigma1 = 14.8811,sigma2 = 34.4593,tau = 0.326045)
# RooRealIntegral::bkg_Int[dimuon_M][ Int bkgd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=