# %%
import ROOT
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.28/04

# %%
ROOT.EnableImplicitMT(10)

# %% [markdown]
# Lemos os datos

# %%
pathdata = "/rxc_lustre/ivan.cambon/TrackCalibmu_AA_tuples/data/NeNe_2025/00319263_*_1.trackeff_muons_nene.root"

tdf = ROOT.RDataFrame("charmonium_mu_mu_Down_mup_Tag/DecayTree", pathdata)

# %% [markdown]
# Aplicamos os mesmos cortes que en OO (sistema de referencia por ser o que máis estatística ten)

# %%
dataMupDowntag_bkg = tdf.Filter("dimuon_BPVIP < 0.35 && dimuon_DOCA_12 < 0.5 &&  dimuon_PT > 2000 && mum_CHI2DOF < 1.5 && mum_P > 1000 && mum_PID_MU > 0 && mum_PT > 1500 && mup_CHI2DOF < 1.2")

# %% [markdown]
# Ploteamos para ver a diferencia entre os datos sen cortes a datos con cortes. Deberíase apreciar un pico na masa do J/psi

# %%
# Crear histogramas (RResultPtr)
h_mass_before = tdf.Histo1D(("h_mass_before","Dimuon mass before cuts",100,2600,3600), "dimuon_M")
h_mass_after  = dataMupDowntag_bkg.Histo1D(("h_mass_after","Dimuon mass after cuts",100,2600,3600), "dimuon_M")

# Converter a TH1 reais
hist_before = h_mass_before.GetValue()
hist_after  = h_mass_after.GetValue()

# Debuxar
c = ROOT.TCanvas("c", "Dimuon mass", 800, 600)

hist_before.SetLineColor(ROOT.kBlack)
hist_before.SetLineWidth(2)

hist_after.SetLineColor(ROOT.kRed)
hist_after.SetLineWidth(2)

# Debuxamos normalizado
hist_after.DrawNormalized("HIST")
hist_before.DrawNormalized("HIST SAME")

# Lenda
leg = ROOT.TLegend(0.75, 0.8, 0.92, 0.92)
leg.AddEntry(hist_before, "Datos crus", "l")
leg.AddEntry(hist_after, "Datos post cortes", "l")
leg.Draw()

# Estilo LHCb
ROOT.gROOT.ProcessLine(".L lhcbStyle.C")
ROOT.lhcbStyle()

c.Draw()
c.SaveAs("dimuon_mass_Down_corte_vs_uncut.png")

# %% [markdown]
# Definimos a continuación os samples match (hai long track asociada, detectouno o Sci-Fi) e fail (non foi detectado polo Sci-Fi)

# %%
match = dataMupDowntag_bkg.Filter("nMatch > 0")
fail = dataMupDowntag_bkg.Filter("nMatch == 0")
tag = dataMupDowntag_bkg

# %% [markdown]
# Ploteamos os samples para ver as súas formas

# %%
c = ROOT.TCanvas("c", "", 800, 600)
h_tag   = dataMupDowntag_bkg.Histo1D(("tag","",100,2800,3400),"dimuon_M")
h_match = match.Histo1D(("match","",100,2800,3400),"dimuon_M")
h_fail  = fail.Histo1D(("fail","",100,2800,3400),"dimuon_M")

hist_tag   = h_tag.GetValue()
hist_match = h_match.GetValue()
hist_fail  = h_fail.GetValue()

hist_tag.SetLineColor(ROOT.kBlack)
hist_match.SetLineColor(ROOT.kBlue)
hist_fail.SetLineColor(ROOT.kRed)

hist_tag.GetXaxis().SetTitle("m_{#mu#mu} [MeV/c^{2}]")
hist_tag.GetYaxis().SetTitle("Eventos")
hist_tag.SetMinimum(0)
hist_tag.Draw("HIST")
hist_match.Draw("HIST SAME")
hist_fail.Draw("HIST SAME")

leg = ROOT.TLegend(0.65, 0.75, 0.9, 0.9)
leg.SetBorderSize(0)
leg.SetFillStyle(0)
leg.AddEntry(hist_tag,   "Tag",   "l")
leg.AddEntry(hist_match, "Match", "l")
leg.AddEntry(hist_fail,  "Fail",  "l")
leg.Draw()

ROOT.gROOT.ProcessLine(".L lhcbStyle.C")
ROOT.lhcbStyle()

c.Draw()
c.SaveAs("NeNe_match_vs_fail_Down.png")
# Out:
# -------------------------
# Set LHCb Style - May 2021
# -------------------------
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file NeNe_match_vs_fail_Down.png has been created

# %% [markdown]
# Pasamos agora a facer os fits. Para traballar con RooFit primeiro temos que definir a variable que imos usar e ler os datos con ROOT.RooDataSet.from_numpy

# %%
mass = ROOT.RooRealVar("dimuon_M", "m(#mu#mu) [MeV/c^{2}]", 2800, 3400) 

data_match = match.AsNumpy(["dimuon_M"])
roo_data_match = ROOT.RooDataSet.from_numpy(
    {"dimuon_M": data_match["dimuon_M"]},
    [mass]
)

data_fail = fail.AsNumpy(["dimuon_M"])
roo_data_fail = ROOT.RooDataSet.from_numpy(
    {"dimuon_M": data_fail["dimuon_M"]},
    [mass])


data_tag = dataMupDowntag_bkg.AsNumpy(["dimuon_M"])
roo_data_tag = ROOT.RooDataSet.from_numpy(
    {"dimuon_M": data_tag["dimuon_M"]},
    [mass]
)
# Out:
# [#0] WARNING:DataHandling -- RooDataSet.from_numpy() Ignored 28558 out-of-range events
# [#0] WARNING:DataHandling -- RooDataSet.from_numpy() Ignored 1355 out-of-range events
# [#0] WARNING:DataHandling -- RooDataSet.from_numpy() Ignored 29913 out-of-range events

# %% [markdown]
# Unha vez definida a variable de masa, pasamos cos fits. Para o sample match usamos un axuste a unha exponencial+gaussiana+CB

# %%
# SAMPLE MATCH
alpha = ROOT.RooRealVar("alpha", "alpha", 1.99966)
alpha.setConstant(True) # ¡Moi importante! Isto evita que MINUIT os toque
n = ROOT.RooRealVar("n", "n", 2.5)
n.setConstant(True)

# 3. Parámetros LIBRES (inicializados cos valores do MC pero con marxe)
mean   = ROOT.RooRealVar("mean", "mean", 3098.32, 3070, 3130)
# Damos un pouco máis de límite superior aos sigmas porque os datos reais teñen peor resolución
sigma1 = ROOT.RooRealVar("sigma1", "sigma gauss", 13.51, 5, 25)  
sigma2 = ROOT.RooRealVar("sigma2", "sigma cb", 26.76, 15, 300)
sig_frac = ROOT.RooRealVar("sig_frac", "fraction Gauss/CB", 0.714, 0, 1)

# 4. Construción do sinal
gauss = ROOT.RooGaussian("gauss", "Gaussian", mass, mean, sigma1)
cb    = ROOT.RooCBShape("cb", "Crystal Ball", mass, mean, sigma2, alpha, n)
signal = ROOT.RooAddPdf("signal", "Gauss + CB", [gauss, cb], [sig_frac])

# 5. Parámetros LIBRES do Fondo
tau = ROOT.RooRealVar("tau", "tau bkg", -0.0127, -1.0, 0.5)
bkg = ROOT.RooExponential("bkg", "Exponential Bkg", mass, tau)

# 6. Yields (Número de eventos). Subimos moito os límites iniciais porque tes máis datos
nsig = ROOT.RooRealVar("nsig", "N signal", 28000, 0, 200000)
nbkg = ROOT.RooRealVar("nbkg", "N background", 20000, 0, 200000)

# 7. Modelo Total e Axuste
model_total = ROOT.RooAddPdf("model_total", "Signal + Background", [signal, bkg], [nsig, nbkg])

# Asumindo que os teus datos de 'match' están nun RooDataSet ou RooDataHist chamado roo_data_match
model_total.fitTo(roo_data_match)
# Out:
# <cppyy.gbl.RooFitResult object at 0x(nil)>
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (gauss,cb,bkg)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 mean         3.09832e+03  6.00000e+00    3.07000e+03  3.13000e+03
#      2 nbkg         2.00000e+04  1.00000e+04    0.00000e+00  2.00000e+05
#      3 nsig         2.80000e+04  1.40000e+04    0.00000e+00  2.00000e+05
#      4 sig_frac     7.14000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      5 sigma1       1.35100e+01  2.00000e+00    5.00000e+00  2.50000e+01
#      6 sigma2       2.67600e+01  5.88000e+00    1.50000e+01  3.00000e+02
#      7 tau         -1.27000e-02  1.50000e-01   -1.00000e+00  5.00000e-01
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        3500           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-146094 FROM MIGRAD    STATUS=INITIATE      166 CALLS         167 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  mean         3.09832e+03   6.00000e+00   0.00000e+00  -3.05946e+02
#    2  nbkg         2.00000e+04   1.00000e+04   0.00000e+00  -1.63640e+04
#    3  nsig         2.80000e+04   1.40000e+04   0.00000e+00   1.94354e+04
#    4  sig_frac     2.18614e-06   1.00000e-01   0.00000e+00  -3.15928e+00
#    5  sigma1       5.05770e+00   2.00000e+00   0.00000e+00   2.12630e-04
#    6  sigma2       8.40755e+01   5.88000e+00   0.00000e+00  -1.57613e+04
#    7  tau         -2.01689e-03   1.50000e-01   1.50539e-02  -2.06450e+05
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -3.1814e-02  2.7080e-01  9.1766e-01  1.0520e+00  1.0925e+00  1.1714e+00  2.5274e+00
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 0.034341 TO DIAGONAL.
#  FCN=-152728 FROM HESSE     STATUS=NOT POSDEF     60 CALLS        1059 TOTAL
#                      EDM=0.00295695    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  mean         3.09376e+03   1.24510e+00   1.13480e-02   3.36037e-02
#    2  nbkg         4.35021e+04   1.53341e+03   6.96267e-04  -7.88066e-01
#    3  nsig         2.11033e+03   1.56225e+03   1.42870e-03  -1.33220e+00
#    4  sig_frac     6.58385e-01   3.70470e-01   2.15088e-02  -1.00910e-01
#    5  sigma1       1.65442e+01   2.00249e+00   3.10093e-02   8.77462e-02
#    6  sigma2       2.72611e+02   1.49814e+02   5.00000e-01   1.18610e-02
#    7  tau         -9.83829e-04   4.66616e-05   1.07390e-05   3.75628e+01
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -1.7475e-02  3.6277e-01  9.2195e-01  1.0521e+00  1.0655e+00  1.1817e+00  2.4334e+00
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 0.019909 TO DIAGONAL.
#  FCN=-152728 FROM MIGRAD    STATUS=CONVERGED    1187 CALLS        1188 TOTAL
#                      EDM=9.48661e-05    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  mean         3.09376e+03   1.23556e+00   1.13550e-02  -1.50620e-02
#    2  nbkg         4.33832e+04   1.58237e+03   6.96789e-04  -9.18948e-01
#    3  nsig         2.22930e+03   1.59519e+03   1.44456e-03   2.20941e-01
#    4  sig_frac     6.24175e-01   3.87541e-01   2.03032e-02   4.46988e-02
#    5  sigma1       1.65530e+01   1.46038e+00   3.10465e-02   2.58387e-03
#    6  sigma2       2.99955e+02   2.82440e+02   5.00000e-01   2.50658e-04
#    7  tau         -9.86602e-04   4.52221e-05   1.07622e-05  -4.75891e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  7    ERR DEF=0.5
#   1.528e+00  1.893e+01 -1.926e+01 -8.717e-04 -2.528e-01  1.450e+00 -1.241e-06
#   1.893e+01  2.504e+06 -2.504e+06  7.010e+02 -4.176e+01  3.800e+04  5.572e-02
#  -1.926e+01 -2.504e+06  2.550e+06 -7.131e+02  4.247e+01 -3.865e+04 -5.668e-02
#  -8.717e-04  7.010e+02 -7.131e+02  2.018e-01  3.329e-02  1.042e+01  1.586e-05
#  -2.528e-01 -4.176e+01  4.247e+01  3.329e-02  2.148e+00 -9.168e+00 -8.779e-07
#   1.450e+00  3.800e+04 -3.865e+04  1.042e+01 -9.168e+00  1.071e+03  8.883e-04
#  -1.241e-06  5.572e-02 -5.668e-02  1.586e-05 -8.779e-07  8.883e-04  2.045e-09
# ERR MATRIX NOT POS-DEF
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7
#         1  0.14915   1.000  0.010 -0.010 -0.002 -0.140  0.036 -0.022
#         2  0.99109   0.010  1.000 -0.991  0.986 -0.018  0.734  0.779
#         3  0.99757  -0.010 -0.991  1.000 -0.994  0.018 -0.740 -0.785
#         4  0.99679  -0.002  0.986 -0.994  1.000  0.051  0.708  0.781
#         5  0.64154  -0.140 -0.018  0.018  0.051  1.000 -0.191 -0.013
#         6  0.78123   0.036  0.734 -0.740  0.708 -0.191  1.000  0.600
#         7  0.78630  -0.022  0.779 -0.785  0.781 -0.013  0.600  1.000
#  ERR MATRIX NOT POS-DEF
#  **********
#  **    7 **HESSE        3500
#  **********
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -9.7147e-04  3.4158e-01  9.1670e-01  1.0515e+00  1.0711e+00  1.1876e+00  2.4325e+00
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 0.003404 TO DIAGONAL.
#  FCN=-152728 FROM HESSE     STATUS=NOT POSDEF     54 CALLS        1242 TOTAL
#                      EDM=8.90576e-05    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE     INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  mean         3.09376e+03   1.25089e+00   4.54198e-04  -2.09670e-01
#    2  nbkg         4.33832e+04   1.60315e+03   1.39358e-04  -6.01849e-01
#    3  nsig         2.22930e+03   1.59347e+03   5.77823e-05  -1.35925e+00
#    4  sig_frac     6.24175e-01   3.87076e-01   8.12129e-04   2.50977e-01
#    5  sigma1       1.65530e+01   1.52126e+00   1.24186e-03  -1.24104e+01
#    6  sigma2       2.99955e+02   2.66409e+02   5.00000e-01   1.59582e+00
#    7  tau         -9.86602e-04   4.58055e-05   4.30487e-07   3.38442e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  7    ERR DEF=0.5
#   1.566e+00  1.323e+01 -1.327e+01 -3.972e-03 -3.191e-01  1.662e+00 -1.428e-06
#   1.323e+01  2.570e+06 -2.534e+06  7.087e+02 -2.554e+01  3.404e+04  5.735e-02
#  -1.327e+01 -2.534e+06  2.544e+06 -7.107e+02  2.561e+01 -3.414e+04 -5.751e-02
#  -3.972e-03  7.087e+02 -7.107e+02  2.011e-01  4.405e-02  9.087e+00  1.608e-05
#  -3.191e-01 -2.554e+01  2.561e+01  4.405e-02  2.333e+00 -1.041e+01 -4.928e-07
#   1.662e+00  3.404e+04 -3.414e+04  9.087e+00 -1.041e+01  9.644e+02  8.021e-04
#  -1.428e-06  5.735e-02 -5.751e-02  1.608e-05 -4.928e-07  8.021e-04  2.098e-09
# ERR MATRIX NOT POS-DEF
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7
#         1  0.17456   1.000  0.007 -0.007 -0.007 -0.167  0.043 -0.025
#         2  0.99118   0.007  1.000 -0.991  0.986 -0.010  0.684  0.781
#         3  0.99752  -0.007 -0.991  1.000 -0.994  0.011 -0.689 -0.787
#         4  0.99673  -0.007  0.986 -0.994  1.000  0.064  0.652  0.783
#         5  0.67005  -0.167 -0.010  0.011  0.064  1.000 -0.219 -0.007
#         6  0.74828   0.043  0.684 -0.689  0.652 -0.219  1.000  0.564
#         7  0.78855  -0.025  0.781 -0.787  0.783 -0.007  0.564  1.000
#  ERR MATRIX NOT POS-DEF
#  **********
#  **    8 **SET ERR         0.5
#  **********
#  **********
#  **    9 **SET PRINT           1
#  **********
#  **********
#  **   10 **HESSE        3500
#  **********
#  EIGENVALUES OF SECOND-DERIVATIVE MATRIX:
#         -4.4896e-04  3.4086e-01  9.1652e-01  1.0514e+00  1.0713e+00  1.1879e+00  2.4325e+00
#  MINUIT WARNING IN HESSE
#  ============== MATRIX FORCED POS-DEF BY ADDING 0.002881 TO DIAGONAL.
#  FCN=-152728 FROM HESSE     STATUS=NOT POSDEF     54 CALLS        1296 TOTAL
#                      EDM=8.87965e-05    STRATEGY= 1      ERR MATRIX NOT POS-DEF
#   EXT PARAMETER                APPROXIMATE     INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  mean         3.09376e+03   1.25141e+00   9.08397e-05  -2.09670e-01
#    2  nbkg         4.33832e+04   1.60403e+03   2.78715e-05  -6.01849e-01
#    3  nsig         2.22930e+03   1.59341e+03   1.15565e-05  -1.35925e+00
#    4  sig_frac     6.24175e-01   3.87044e-01   1.62426e-04   2.50977e-01
#    5  sigma1       1.65530e+01   1.52339e+00   2.48372e-04  -1.24104e+01
#    6  sigma2       2.99955e+02   2.65741e+02   5.00000e-01   1.59582e+00
#    7  tau         -9.86602e-04   4.58248e-05   8.60973e-08   3.38442e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  7    ERR DEF=0.5
#   1.567e+00  1.314e+01 -1.317e+01 -4.055e-03 -3.216e-01  1.673e+00 -1.432e-06
#   1.314e+01  2.573e+06 -2.536e+06  7.090e+02 -2.638e+01  3.392e+04  5.741e-02
#  -1.317e+01 -2.536e+06  2.544e+06 -7.106e+02  2.644e+01 -3.400e+04 -5.754e-02
#  -4.055e-03  7.090e+02 -7.106e+02  2.011e-01  4.404e-02  9.044e+00  1.608e-05
#  -3.216e-01 -2.638e+01  2.644e+01  4.404e-02  2.339e+00 -1.047e+01 -5.106e-07
#   1.673e+00  3.392e+04 -3.400e+04  9.044e+00 -1.047e+01  9.613e+02  7.994e-04
#  -1.432e-06  5.741e-02 -5.754e-02  1.608e-05 -5.106e-07  7.994e-04  2.100e-09
# ERR MATRIX NOT POS-DEF
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7
#         1  0.17546   1.000  0.007 -0.007 -0.007 -0.168  0.043 -0.025
#         2  0.99118   0.007  1.000 -0.991  0.986 -0.011  0.682  0.781
#         3  0.99752  -0.007 -0.991  1.000 -0.994  0.011 -0.688 -0.787
#         4  0.99673  -0.007  0.986 -0.994  1.000  0.064  0.651  0.783
#         5  0.67101  -0.168 -0.011  0.011  0.064  1.000 -0.221 -0.007
#         6  0.74719   0.043  0.682 -0.688  0.651 -0.221  1.000  0.563
#         7  0.78863  -0.025  0.781 -0.787  0.783 -0.007  0.563  1.000
#  ERR MATRIX NOT POS-DEF
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %% [markdown]
# Para o tag usaremos tamén o combo de exponencial + gaussiana + CB xa que ten a mesma forma que o match

# %%
# SAMPLE TAG
alpha_tag = ROOT.RooRealVar("alpha", "alpha", 1.99966)
alpha_tag.setConstant(True)
n_tag = ROOT.RooRealVar("n", "n", 49.53)
n_tag.setConstant(True)

# 2. Parámetros LIBRES do Tag (Poden variar lixeiramente respecto ao match)
mean_tag   = ROOT.RooRealVar("mean_tag", "mean", 3098.32, 3070, 3130)
sigma1_tag = ROOT.RooRealVar("sigma1_tag", "sigma gauss", 13.51, 5, 25)  
sigma2_tag = ROOT.RooRealVar("sigma2_tag", "sigma cb", 26.76, 15, 60)
sig_frac_tag = ROOT.RooRealVar("sig_frac_tag", "fraction Gauss/CB", 0.714, 0, 1)

# Construción do sinal do Tag
gauss_tag = ROOT.RooGaussian("gauss_tag", "Gaussian", mass, mean_tag, sigma1_tag)
cb_tag    = ROOT.RooCBShape("cb_tag", "Crystal Ball", mass, mean_tag, sigma2_tag, alpha_tag, n_tag)
signal_tag = ROOT.RooAddPdf("signal_tag", "Gauss + CB", [gauss_tag, cb_tag], [sig_frac_tag])

# 3. Parámetros LIBRES do Fondo do Tag
tau_tag = ROOT.RooRealVar("tau_tag", "tau bkg", -0.01274, -1.0, 0.5)
bkg_tag = ROOT.RooExponential("bkg_tag", "Exponential Bkg", mass, tau_tag)

# 4. Yields (Número de eventos). Lixeiramente superiores porque Tag = Match + Fail
nsig_tag = ROOT.RooRealVar("nsig_tag", "N signal tag", 30000, 0, 300000)
nbkg_tag = ROOT.RooRealVar("nbkg_tag", "N background tag", 25000, 0, 300000)

# 5. Modelo Total e Axuste á mostra TAG
model_tag = ROOT.RooAddPdf("model_tag", "Signal + Background Tag", [signal_tag, bkg_tag], [nsig_tag, nbkg_tag])

# Lanzamos o fit contra os datos que me dixeches
model_tag.fitTo(roo_data_tag)
# Out:
# <cppyy.gbl.RooFitResult object at 0x(nil)>
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (gauss_tag,cb_tag,bkg_tag)
#  **********
#  **   11 **SET PRINT           1
#  **********
#  **********
#  **   12 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 mean_tag     3.09832e+03  6.00000e+00    3.07000e+03  3.13000e+03
#      2 nbkg_tag     2.50000e+04  1.25000e+04    0.00000e+00  3.00000e+05
#      3 nsig_tag     3.00000e+04  1.50000e+04    0.00000e+00  3.00000e+05
#      4 sig_frac_tag   7.14000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      5 sigma1_tag   1.35100e+01  2.00000e+00    5.00000e+00  2.50000e+01
#      6 sigma2_tag   2.67600e+01  4.50000e+00    1.50000e+01  6.00000e+01
#      7 tau_tag     -1.27400e-02  1.50000e-01   -1.00000e+00  5.00000e-01
#  **********
#  **   13 **SET ERR         0.5
#  **********
#  **********
#  **   14 **SET PRINT           1
#  **********
#  **********
#  **   15 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   16 **MIGRAD        3500           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-151511 FROM MIGRAD    STATUS=INITIATE      191 CALLS         192 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  mean_tag     3.12520e+03   6.00000e+00  -5.68406e-01   3.45253e+00
#    2  nbkg_tag     2.50000e+04   1.25000e+04   0.00000e+00  -2.11981e+04
#    3  nsig_tag     3.00000e+04   1.50000e+04   0.00000e+00   4.12333e+04
#    4  sig_frac_tag   7.49431e-05   1.00000e-01   0.00000e+00   3.91028e+01
#    5  sigma1_tag   2.49971e+01   2.00000e+00   0.00000e+00  -1.25763e-03
#    6  sigma2_tag   5.99983e+01   4.50000e+00   0.00000e+00  -5.15669e+01
#    7  tau_tag     -2.30136e-03   1.50000e-01   0.00000e+00  -2.63035e+05
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-161618 FROM MIGRAD    STATUS=CONVERGED    1269 CALLS        1270 TOTAL
#                      EDM=2.15853e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  mean_tag     3.09391e+03   1.20255e+00   1.12337e-02   1.12910e-02
#    2  nbkg_tag     4.61332e+04   2.42768e+02   5.58146e-04  -4.90444e-01
#    3  nsig_tag     1.51360e+03   1.19632e+02   1.08292e-03   4.29509e-01
#    4  sig_frac_tag   3.60298e-01   1.54648e-01   4.20282e-02   6.99665e-03
#    5  sigma1_tag   1.04162e+01   2.00132e+00   4.17818e-02   2.17571e-02
#    6  sigma2_tag   2.43044e+01   4.84787e+00   3.88179e-02   4.34227e-03
#    7  tau_tag     -9.80770e-04   2.72095e-05   1.06437e-05   5.70450e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  7    ERR DEF=0.5
#   1.447e+00 -2.053e+00 -2.048e+00 -2.729e-02  2.442e-01 -6.927e-01 -1.457e-06
#  -2.053e+00  5.894e+04  1.280e+04  6.772e-01 -1.305e+01  2.971e+02  2.125e-04
#  -2.048e+00  1.280e+04  1.431e+04  6.758e-01 -1.304e+01  2.967e+02  2.124e-04
#  -2.729e-02  6.772e-01  6.758e-01  2.479e-02 -2.221e-01  5.166e-01  4.522e-08
#   2.442e-01 -1.305e+01 -1.304e+01 -2.221e-01  4.075e+00 -3.223e+00 -5.416e-07
#  -6.927e-01  2.971e+02  2.967e+02  5.166e-01 -3.223e+00  2.408e+01  5.629e-06
#  -1.457e-06  2.125e-04  2.124e-04  4.522e-08 -5.416e-07  5.629e-06  7.404e-10
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7
#         1  0.15374   1.000 -0.007 -0.014 -0.144  0.101 -0.117 -0.045
#         2  0.44349  -0.007  1.000  0.441  0.018 -0.027  0.249  0.032
#         3  0.72086  -0.014  0.441  1.000  0.036 -0.054  0.505  0.065
#         4  0.88735  -0.144  0.018  0.036  1.000 -0.699  0.669  0.011
#         5  0.75174   0.101 -0.027 -0.054 -0.699  1.000 -0.325 -0.010
#         6  0.85311  -0.117  0.249  0.505  0.669 -0.325  1.000  0.042
#         7  0.07883  -0.045  0.032  0.065  0.011 -0.010  0.042  1.000
#  **********
#  **   17 **SET ERR         0.5
#  **********
#  **********
#  **   18 **SET PRINT           1
#  **********
#  **********
#  **   19 **HESSE        3500
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-161618 FROM HESSE     STATUS=OK             50 CALLS        1320 TOTAL
#                      EDM=2.40039e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  mean_tag     3.09391e+03   1.22278e+00   4.49349e-04  -2.04476e-01
#    2  nbkg_tag     4.61332e+04   2.42816e+02   1.11629e-04  -7.64873e-01
#    3  nsig_tag     1.51360e+03   1.19762e+02   4.33167e-05  -1.71298e+00
#    4  sig_frac_tag   3.60298e-01   2.17962e-01   1.68113e-03  -9.14161e+00
#    5  sigma1_tag   1.04162e+01   2.84109e+00   1.67127e-03   5.80701e+00
#    6  sigma2_tag   2.43044e+01   5.58547e+00   1.55272e-03   3.76829e+00
#    7  tau_tag     -9.80770e-04   2.72118e-05   4.25749e-07   3.38450e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  7    ERR DEF=0.5
#   1.496e+00 -2.502e+00 -2.502e+00 -6.390e-02  7.122e-01 -1.342e+00 -1.524e-06
#  -2.502e+00  5.896e+04  1.283e+04  7.480e-01 -2.183e+01  2.938e+02  2.143e-04
#  -2.502e+00  1.283e+04  1.434e+04  7.480e-01 -2.183e+01  2.938e+02  2.144e-04
#  -6.390e-02  7.480e-01  7.480e-01  5.119e-02 -5.682e-01  9.906e-01  9.145e-08
#   7.122e-01 -2.183e+01 -2.183e+01 -5.682e-01  8.363e+00 -9.825e+00 -1.263e-06
#  -1.342e+00  2.938e+02  2.938e+02  9.906e-01 -9.825e+00  3.223e+01  6.399e-06
#  -1.524e-06  2.143e-04  2.144e-04  9.145e-08 -1.263e-06  6.399e-06  7.405e-10
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6      7
#         1  0.23612   1.000 -0.008 -0.017 -0.231  0.201 -0.193 -0.046
#         2  0.44385  -0.008  1.000  0.441  0.014 -0.031  0.213  0.032
#         3  0.72159  -0.017  0.441  1.000  0.028 -0.063  0.432  0.066
#         4  0.94714  -0.231  0.014  0.028  1.000 -0.868  0.771  0.015
#         5  0.88778   0.201 -0.031 -0.063 -0.868  1.000 -0.598 -0.016
#         6  0.89205  -0.193  0.213  0.432  0.771 -0.598  1.000  0.041
#         7  0.07989  -0.046  0.032  0.066  0.015 -0.016  0.041  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %% [markdown]
# Por último para o sample fail axustamos os datos a unha exponencial

# %%
# SAMPLE FAIL
#mass = ROOT.RooRealVar("mass", "m_{#mu#mu} [MeV/c^{2}]", 2800, 3400)

# 2. O parámetro da exponencial para o Fail
# Inicializámolo nun valor pequeno negativo.
tau_fail = ROOT.RooRealVar("tau_fail", "tau fail", -0.001, -0.02, 0.0)

# 3. A función Exponencial pura
bkg_fail = ROOT.RooExponential("bkg_fail", "Exponential Bkg Fail", mass, tau_fail)

# 4. Número de eventos (Yield). 
# Mirando a túa gráfica, a mostra fail ten moi poucos eventos en comparación co resto.
nbkg_fail = ROOT.RooRealVar("nbkg_fail", "N background fail", 1000, 0, 50000)

# 5. Creamos o modelo estendido. 
# Aínda que é unha soa función, metémola nun RooAddPdf para que MINUIT calcule o nbkg_fail
model_fail = ROOT.RooAddPdf("model_fail", "Background Only Fail", [bkg_fail], [nbkg_fail])

# 6. Lanzamos o fit (supoñendo que a túa variable de datos se chama roo_data_fail)
model_fail.fitTo(roo_data_fail)
# Out:
# <cppyy.gbl.RooFitResult object at 0x(nil)>
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (bkg_fail)
#  **********
#  **    1 **SET PRINT           1
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 nbkg_fail    1.00000e+03  5.00000e+02    0.00000e+00  5.00000e+04
#      2 tau_fail    -1.00000e-03  5.00000e-04   -2.00000e-02  0.00000e+00
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           1
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **    6 **MIGRAD        1000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=-81.1979 FROM MIGRAD    STATUS=INITIATE        8 CALLS           9 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  nbkg_fail    1.00000e+03   5.00000e+02   7.39156e-02  -7.23800e+03
#    2  tau_fail    -1.00000e-03   5.00000e-04   1.18625e-01   5.20479e+01
#                                ERR DEF= 0.5
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-492.539 FROM MIGRAD    STATUS=CONVERGED      37 CALLS          38 TOTAL
#                      EDM=2.25058e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  nbkg_fail    2.03409e+03   4.51013e+01   6.99270e-05   4.42603e-01
#    2  tau_fail    -1.19942e-03   1.29669e-04   4.21498e-04   1.57161e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   2.034e+03  0.000e+00
#   0.000e+00  1.682e-08
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.00000   1.000  0.000
#         2  0.00000   0.000  1.000
#  **********
#  **    7 **SET ERR         0.5
#  **********
#  **********
#  **    8 **SET PRINT           1
#  **********
#  **********
#  **    9 **HESSE        1000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=-492.539 FROM HESSE     STATUS=OK             10 CALLS          48 TOTAL
#                      EDM=2.25078e-05    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  nbkg_fail    2.03409e+03   4.51013e+01   1.39854e-05  -1.16462e+00
#    2  tau_fail    -1.19942e-03   1.29669e-04   8.42996e-05   1.07598e+00
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  2    ERR DEF=0.5
#   2.034e+03  0.000e+00
#   0.000e+00  1.682e-08
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2
#         1  0.00000   1.000  0.000
#         2  0.00000   0.000  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %% [markdown]
# Ploteamos agora os datos xunto cos fits

# %%
# Creamos o frame
frame_all = mass.frame(ROOT.RooFit.Title("Comparacion Tag vs Match vs Fail"))

# 1. TAG (Datos e modelo en NEGRO por defecto)
roo_data_tag.plotOn(frame_all, ROOT.RooFit.Name("DataTag")) 
model_tag.plotOn(frame_all, ROOT.RooFit.Name("ModelTag"))

# 2. MATCH (Datos e modelo en VERMELLO continuo)
roo_data_match.plotOn(frame_all, 
                      ROOT.RooFit.Name("DataMatch"), 
                      ROOT.RooFit.MarkerColor(ROOT.kBlack), 
                      ROOT.RooFit.LineColor(ROOT.kBlack)) 

model_total.plotOn(frame_all, 
                   ROOT.RooFit.Name("ModelMatch"), 
                   ROOT.RooFit.LineColor(ROOT.kRed)) 

# 3. FAIL (Datos e modelo en VERDE continuo)
roo_data_fail.plotOn(frame_all, 
                      ROOT.RooFit.Name("DataFail"), 
                      ROOT.RooFit.MarkerColor(ROOT.kBlack), 
                      ROOT.RooFit.LineColor(ROOT.kBlack))

model_fail.plotOn(frame_all, 
                   ROOT.RooFit.Name("ModelFail"), 
                   ROOT.RooFit.LineColor(ROOT.kGreen))

# Debuxamos
c_final = ROOT.TCanvas("c_final", "Canvas Final", 800, 600)
leg = ROOT.TLegend(0.80, 0.65, 0.90, 0.88)
leg.SetBorderSize(0)      # Quítalle o bordo negro á caixa para que quede máis pro
leg.SetFillStyle(0)       # Fai que o fondo da lenda sexa transparente
leg.SetTextSize(0.035)    # Tamaño da letra

# Engadimos os modelos usando os nomes exactos. 
# O "L" significa que queremos que na lenda se debuxe unha Liña.
leg.AddEntry(frame_all.findObject("ModelTag"), "Tag", "L")
leg.AddEntry(frame_all.findObject("ModelMatch"), "Match", "L")
leg.AddEntry(frame_all.findObject("ModelFail"), "Fail", "L")


ROOT.gROOT.ProcessLine(".L lhcbStyle.C")
ROOT.lhcbStyle()
frame_all.Draw()
leg.Draw("SAME")
c_final.Draw()
title_text = ROOT.TLatex()
title_text.SetNDC()              # Usa coordenadas da pantalla (0 a 1) no canto das dos eixes
title_text.SetTextSize(0.045)    # Tamaño do texto
title_text.SetTextFont(62)       # Tipo de letra (62 adoita ser negrita en ROOT)
title_text.SetTextAlign(21)      # Aliñación: 2 (centro horizontal), 1 (abaixo vertical)

# Debuxamos o título na posición X=0.5 (centro) e Y=0.92 (arriba do todo)
title_text.DrawLatex(0.5, 0.96, "Axustes Downstream NeNe")
c_final.SaveAs("Axustes_Down_NeNe.png")
# Out:
# [#1] INFO:Plotting -- RooPlot::updateFitRangeNorm: New event count of 45613 will supercede previous event count of 47647 for normalization of PDF projections
# [#1] INFO:Plotting -- RooPlot::updateFitRangeNorm: New event count of 2034 will supercede previous event count of 45613 for normalization of PDF projections
# -------------------------
# Set LHCb Style - May 2021
# -------------------------
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c_final
# Info in <TCanvas::Print>: png file Axustes_Down_NeNe.png has been created
