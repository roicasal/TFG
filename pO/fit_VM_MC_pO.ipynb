# %%
import ROOT
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ROOT.EnableImplicitMT(10)

# %% [markdown]
# Neste ficheiro vaise realizar un fit ao montecarlo para entender o comportamento do pico de masa dos samples tag e match, de forma que os resultados obtidos serán usados despois nos datos como parámetros iniciais do fit ou incluso algúns como parámetros fixados

# %% [markdown]
# Comezamos entón por ler os datos de MC

# %%
pathmc = '/rxc_lustre/ivan.cambon/TrackCalibmu_AA_tuples/MC/pO_2025/trackeffmu_pO_mc_2025.root'


tdf_mc = ROOT.RDataFrame("charmonium_mu_mu_VM_mup_Tag/DecayTree", pathmc)

# %% [markdown]
# Aplicamos os mesmos filtros que en data:

# %%
datamc = tdf_mc.Filter("dimuon_BPVIP < 0.35 && dimuon_DOCA_12 < 0.5 &&  dimuon_PT > 2000 && mum_CHI2DOF < 1.5 && mum_P > 1000 && mum_PID_MU > 0 && mum_PT > 1500 && mup_CHI2DOF < 1.2")
datamc = datamc.Filter("abs(dimuon_TRUEID)==443")

# %% [markdown]
# Definimos a variable sobre a que facer os fits (masa) e a continuación realízase o fit a unha Gaussiana + CB

# %%
mass = ROOT.RooRealVar("dimuon_M", "m(#mu#mu)", 2600, 3600) 
data = datamc.AsNumpy(["dimuon_M"])
roo_data = ROOT.RooDataSet.from_numpy(
    {"dimuon_M": data["dimuon_M"]},
    [mass]
)

# %%
# 1. Variables do sinal
mean   = ROOT.RooRealVar("mean", "mean", 3096, 3070, 3130)
sigma1 = ROOT.RooRealVar("sigma1", "sigma gauss", 8, 2, 40)  # O núcleo estreito
sigma2 = ROOT.RooRealVar("sigma2", "sigma cb", 25, 15, 100)   # As colas
alpha  = ROOT.RooRealVar("alpha", "alpha", 1.5, 0.1, 10)
n      = ROOT.RooRealVar("n", "n", 3, -5, 100)               

# 2. Funcións do sinal
gauss = ROOT.RooGaussian("gauss", "Gaussian Core", mass, mean, sigma1)
cb    = ROOT.RooCBShape("cb", "Crystal Ball Tail", mass, mean, sigma2, alpha, n)

sig_frac = ROOT.RooRealVar("sig_frac", "fraction Gauss/CB", 0.5, 0, 1)

# Creamos o pdf do sinal combinado
signal = ROOT.RooAddPdf("signal", "Gauss + CB", [gauss, cb], [sig_frac])
#Fiteamos
signal.fitTo(roo_data)
# Out:
# <cppyy.gbl.RooFitResult object at 0x(nil)>
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (gauss,cb)
#  **********
#  **   10 **SET PRINT           1
#  **********
#  **********
#  **   11 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 alpha        1.50000e+00  7.00000e-01    1.00000e-01  1.00000e+01
#      2 mean         3.09600e+03  6.00000e+00    3.07000e+03  3.13000e+03
#      3 n            3.00000e+00  4.00000e+00   -5.00000e+00  1.00000e+02
#      4 sig_frac     5.00000e-01  1.00000e-01    0.00000e+00  1.00000e+00
#      5 sigma1       8.00000e+00  3.00000e+00    2.00000e+00  4.00000e+01
#      6 sigma2       2.50000e+01  5.00000e+00    1.50000e+01  1.00000e+02
#  **********
#  **   12 **SET ERR         0.5
#  **********
#  **********
#  **   13 **SET PRINT           1
#  **********
#  **********
#  **   14 **SET STR           1
#  **********
#  NOW USING STRATEGY  1: TRY TO BALANCE SPEED AGAINST RELIABILITY
#  **********
#  **   15 **MIGRAD        3000           1
#  **********
#  FIRST CALL TO USER FUNCTION AT NEW START POINT, WITH IFLAG=4.
#  START MIGRAD MINIMIZATION.  STRATEGY  1.  CONVERGENCE WHEN EDM .LT. 1.00e-03
#  FCN=266961 FROM MIGRAD    STATUS=INITIATE       26 CALLS          27 TOTAL
#                      EDM= unknown      STRATEGY= 1      NO ERROR MATRIX
#   EXT PARAMETER               CURRENT GUESS       STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        1.50000e+00   7.00000e-01   2.09487e-01   1.58244e+04
#    2  mean         3.09600e+03   6.00000e+00   2.03277e-01  -2.31658e+04
#    3  n            3.00000e+00   4.00000e+00   1.48416e-01   2.24235e+04
#    4  sig_frac     5.00000e-01   1.00000e-01   2.01358e-01   2.51211e+04
#    5  sigma1       8.00000e+00   3.00000e+00   2.23457e-01  -1.12415e+04
#    6  sigma2       2.50000e+01   5.00000e+00   1.88559e-01  -8.19643e+04
#                                ERR DEF= 0.5
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (272957) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=0.92618	mean=3108.86	n=-2.86105	sig_frac=0.12157	sigma1=6.55937	sigma2=37.8557
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 3.52145e-38/16.4419,cb = -nan/-nan), !coefficients=(sig_frac = 0.12157)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 7.67639e-07/16.4419,cb = -nan/-nan), !coefficients=(sig_frac = 0.12157)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 3.43486e-08/16.4419,cb = -nan/-nan), !coefficients=(sig_frac = 0.12157)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 1.76529e-16/16.4419,cb = -nan/-nan), !coefficients=(sig_frac = 0.12157)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0/16.4419,cb = -nan/-nan), !coefficients=(sig_frac = 0.12157)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00587942/16.4419,cb = -nan/-nan), !coefficients=(sig_frac = 0.12157)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 6.22044e-33/16.4419,cb = -nan/-nan), !coefficients=(sig_frac = 0.12157)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0567536/16.4419,cb = -nan/-nan), !coefficients=(sig_frac = 0.12157)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 1.64622e-06/16.4419,cb = -nan/-nan), !coefficients=(sig_frac = 0.12157)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 5.24069e-05/16.4419,cb = -nan/-nan), !coefficients=(sig_frac = 0.12157)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 8.49132e-07/16.4419,cb = -nan/-nan), !coefficients=(sig_frac = 0.12157)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 3.39235e-14/16.4419,cb = -nan/-nan), !coefficients=(sig_frac = 0.12157)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 0.92618,mean = 3108.86,n = -2.86105,sig_frac = 0.12157,sigma1 = 6.55937,sigma2 = 37.8557)
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=3068.94, m0=mean=3108.86, sigma=sigma2=37.8557, alpha=alpha=0.92618, n=n=-2.86105
#      p.d.f value is Not-a-Number @ m=dimuon_M=2794, m0=mean=3108.86, sigma=sigma2=37.8557, alpha=alpha=0.92618, n=n=-2.86105
#      p.d.f value is Not-a-Number @ m=dimuon_M=3020.67, m0=mean=3108.86, sigma=sigma2=37.8557, alpha=alpha=0.92618, n=n=-2.86105
#      p.d.f value is Not-a-Number @ m=dimuon_M=2984.49, m0=mean=3108.86, sigma=sigma2=37.8557, alpha=alpha=0.92618, n=n=-2.86105
#      p.d.f value is Not-a-Number @ m=dimuon_M=3061.77, m0=mean=3108.86, sigma=sigma2=37.8557, alpha=alpha=0.92618, n=n=-2.86105
#      p.d.f value is Not-a-Number @ m=dimuon_M=3072.39, m0=mean=3108.86, sigma=sigma2=37.8557, alpha=alpha=0.92618, n=n=-2.86105
#      p.d.f value is Not-a-Number @ m=dimuon_M=3065.93, m0=mean=3108.86, sigma=sigma2=37.8557, alpha=alpha=0.92618, n=n=-2.86105
#      p.d.f value is Not-a-Number @ m=dimuon_M=3072.21, m0=mean=3108.86, sigma=sigma2=37.8557, alpha=alpha=0.92618, n=n=-2.86105
#      p.d.f value is Not-a-Number @ m=dimuon_M=3060.66, m0=mean=3108.86, sigma=sigma2=37.8557, alpha=alpha=0.92618, n=n=-2.86105
#      p.d.f value is Not-a-Number @ m=dimuon_M=2992.51, m0=mean=3108.86, sigma=sigma2=37.8557, alpha=alpha=0.92618, n=n=-2.86105
#      p.d.f value is Not-a-Number @ m=dimuon_M=3001.56, m0=mean=3108.86, sigma=sigma2=37.8557, alpha=alpha=0.92618, n=n=-2.86105
#      p.d.f value is Not-a-Number @ m=dimuon_M=3063.97, m0=mean=3108.86, sigma=sigma2=37.8557, alpha=alpha=0.92618, n=n=-2.86105
#     ... (remaining 2038 messages suppressed)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3132.94), !jacList=(), !facList=(), !func=cb=0.816737/66.0299, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (272957) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=1.20294	mean=3102.34	n=-0.310771	sig_frac=0.296196	sigma1=39.8269	sigma2=30.7823
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00145574/99.8313,cb = -nan/-nan), !coefficients=(sig_frac = 0.296196)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00827178/99.8313,cb = -nan/-nan), !coefficients=(sig_frac = 0.296196)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00773012/99.8313,cb = -nan/-nan), !coefficients=(sig_frac = 0.296196)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00319818/99.8313,cb = -nan/-nan), !coefficients=(sig_frac = 0.296196)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 5.6586e-16/99.8313,cb = -nan/-nan), !coefficients=(sig_frac = 0.296196)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00983301/99.8313,cb = -nan/-nan), !coefficients=(sig_frac = 0.296196)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00196809/99.8313,cb = -nan/-nan), !coefficients=(sig_frac = 0.296196)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00976698/99.8313,cb = -nan/-nan), !coefficients=(sig_frac = 0.296196)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00840765/99.8313,cb = -nan/-nan), !coefficients=(sig_frac = 0.296196)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00903105/99.8313,cb = -nan/-nan), !coefficients=(sig_frac = 0.296196)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00828969/99.8313,cb = -nan/-nan), !coefficients=(sig_frac = 0.296196)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00375566/99.8313,cb = -nan/-nan), !coefficients=(sig_frac = 0.296196)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 1.20294,mean = 3102.34,n = -0.310771,sig_frac = 0.296196,sigma1 = 39.8269,sigma2 = 30.7823)
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=2726.83, m0=mean=3102.34, sigma=sigma2=30.7823, alpha=alpha=1.20294, n=n=-0.310771
#      p.d.f value is Not-a-Number @ m=dimuon_M=3060.39, m0=mean=3102.34, sigma=sigma2=30.7823, alpha=alpha=1.20294, n=n=-0.310771
#      p.d.f value is Not-a-Number @ m=dimuon_M=3057.86, m0=mean=3102.34, sigma=sigma2=30.7823, alpha=alpha=1.20294, n=n=-0.310771
#      p.d.f value is Not-a-Number @ m=dimuon_M=3047.85, m0=mean=3102.34, sigma=sigma2=30.7823, alpha=alpha=1.20294, n=n=-0.310771
#      p.d.f value is Not-a-Number @ m=dimuon_M=2950.61, m0=mean=3102.34, sigma=sigma2=30.7823, alpha=alpha=1.20294, n=n=-0.310771
#      p.d.f value is Not-a-Number @ m=dimuon_M=3049.76, m0=mean=3102.34, sigma=sigma2=30.7823, alpha=alpha=1.20294, n=n=-0.310771
#      p.d.f value is Not-a-Number @ m=dimuon_M=2832.5, m0=mean=3102.34, sigma=sigma2=30.7823, alpha=alpha=1.20294, n=n=-0.310771
#      p.d.f value is Not-a-Number @ m=dimuon_M=3062.79, m0=mean=3102.34, sigma=sigma2=30.7823, alpha=alpha=1.20294, n=n=-0.310771
#      p.d.f value is Not-a-Number @ m=dimuon_M=2820.18, m0=mean=3102.34, sigma=sigma2=30.7823, alpha=alpha=1.20294, n=n=-0.310771
#      p.d.f value is Not-a-Number @ m=dimuon_M=3002.88, m0=mean=3102.34, sigma=sigma2=30.7823, alpha=alpha=1.20294, n=n=-0.310771
#      p.d.f value is Not-a-Number @ m=dimuon_M=2979.9, m0=mean=3102.34, sigma=sigma2=30.7823, alpha=alpha=1.20294, n=n=-0.310771
#      p.d.f value is Not-a-Number @ m=dimuon_M=3057.68, m0=mean=3102.34, sigma=sigma2=30.7823, alpha=alpha=1.20294, n=n=-0.310771
#     ... (remaining 2038 messages suppressed)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3132.94), !jacList=(), !facList=(), !func=cb=0.61012/-nan, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (272957) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=2.02801	mean=3098.43	n=-0.462907	sig_frac=0.368575	sigma1=39.9979	sigma2=49.9153
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00177578/100.26,cb = -nan/-nan), !coefficients=(sig_frac = 0.368575)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00872062/100.26,cb = -nan/-nan), !coefficients=(sig_frac = 0.368575)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00823506/100.26,cb = -nan/-nan), !coefficients=(sig_frac = 0.368575)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00276224/100.26,cb = -nan/-nan), !coefficients=(sig_frac = 0.368575)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 1.557e-15/100.26,cb = -nan/-nan), !coefficients=(sig_frac = 0.368575)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00993025/100.26,cb = -nan/-nan), !coefficients=(sig_frac = 0.368575)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00235755/100.26,cb = -nan/-nan), !coefficients=(sig_frac = 0.368575)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00947116/100.26,cb = -nan/-nan), !coefficients=(sig_frac = 0.368575)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00883943/100.26,cb = -nan/-nan), !coefficients=(sig_frac = 0.368575)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00936358/100.26,cb = -nan/-nan), !coefficients=(sig_frac = 0.368575)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00873636/100.26,cb = -nan/-nan), !coefficients=(sig_frac = 0.368575)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0032743/100.26,cb = -nan/-nan), !coefficients=(sig_frac = 0.368575)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 2.02801,mean = 3098.43,n = -0.462907,sig_frac = 0.368575,sigma1 = 39.9979,sigma2 = 49.9153)
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=2940.83, m0=mean=3098.43, sigma=sigma2=49.9153, alpha=alpha=2.02801, n=n=-0.462907
#      p.d.f value is Not-a-Number @ m=dimuon_M=2849.7, m0=mean=3098.43, sigma=sigma2=49.9153, alpha=alpha=2.02801, n=n=-0.462907
#      p.d.f value is Not-a-Number @ m=dimuon_M=2834.18, m0=mean=3098.43, sigma=sigma2=49.9153, alpha=alpha=2.02801, n=n=-0.462907
#      p.d.f value is Not-a-Number @ m=dimuon_M=2834.73, m0=mean=3098.43, sigma=sigma2=49.9153, alpha=alpha=2.02801, n=n=-0.462907
#      p.d.f value is Not-a-Number @ m=dimuon_M=2914.06, m0=mean=3098.43, sigma=sigma2=49.9153, alpha=alpha=2.02801, n=n=-0.462907
#      p.d.f value is Not-a-Number @ m=dimuon_M=2978.56, m0=mean=3098.43, sigma=sigma2=49.9153, alpha=alpha=2.02801, n=n=-0.462907
#      p.d.f value is Not-a-Number @ m=dimuon_M=2819.06, m0=mean=3098.43, sigma=sigma2=49.9153, alpha=alpha=2.02801, n=n=-0.462907
#      p.d.f value is Not-a-Number @ m=dimuon_M=2960.53, m0=mean=3098.43, sigma=sigma2=49.9153, alpha=alpha=2.02801, n=n=-0.462907
#      p.d.f value is Not-a-Number @ m=dimuon_M=2984.98, m0=mean=3098.43, sigma=sigma2=49.9153, alpha=alpha=2.02801, n=n=-0.462907
#      p.d.f value is Not-a-Number @ m=dimuon_M=2864.24, m0=mean=3098.43, sigma=sigma2=49.9153, alpha=alpha=2.02801, n=n=-0.462907
#      p.d.f value is Not-a-Number @ m=dimuon_M=2974.75, m0=mean=3098.43, sigma=sigma2=49.9153, alpha=alpha=2.02801, n=n=-0.462907
#      p.d.f value is Not-a-Number @ m=dimuon_M=2992.74, m0=mean=3098.43, sigma=sigma2=49.9153, alpha=alpha=2.02801, n=n=-0.462907
#     ... (remaining 1598 messages suppressed)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3132.94), !jacList=(), !facList=(), !func=cb=0.78738/122.083, !sumCat=()
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (272957) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha=2.04156	mean=3099.13	n=-0.389637	sig_frac=0.369482	sigma1=39.993	sigma2=49.458
# RooAddPdf::signal[ sig_frac * gauss + [%] * cb ]
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00171797/100.248,cb = -nan/-nan), !coefficients=(sig_frac = 0.369482)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00864102/100.248,cb = -nan/-nan), !coefficients=(sig_frac = 0.369482)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00814535/100.248,cb = -nan/-nan), !coefficients=(sig_frac = 0.369482)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00284013/100.248,cb = -nan/-nan), !coefficients=(sig_frac = 0.369482)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 1.35064e-15/100.248,cb = -nan/-nan), !coefficients=(sig_frac = 0.369482)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00991357/100.248,cb = -nan/-nan), !coefficients=(sig_frac = 0.369482)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00228736/100.248,cb = -nan/-nan), !coefficients=(sig_frac = 0.369482)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00952442/100.248,cb = -nan/-nan), !coefficients=(sig_frac = 0.369482)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.0087629/100.248,cb = -nan/-nan), !coefficients=(sig_frac = 0.369482)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00930485/100.248,cb = -nan/-nan), !coefficients=(sig_frac = 0.369482)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00865716/100.248,cb = -nan/-nan), !coefficients=(sig_frac = 0.369482)
#      getLogVal() top-level p.d.f evaluates to NaN @ !refCoefNorm=(), !pdfs=(gauss = 0.00336027/100.248,cb = -nan/-nan), !coefficients=(sig_frac = 0.369482)
#     ... (remaining 2038 messages suppressed)
# RooNLLVar::nll_signal_[ parameters=(alpha,mean,n,sig_frac,sigma1,sigma2) ]
#      function value is NAN @ parameters=(alpha = 2.04156,mean = 3099.13,n = -0.389637,sig_frac = 0.369482,sigma1 = 39.993,sigma2 = 49.458)
# RooCBShape::cb[ m=dimuon_M m0=mean sigma=sigma2 alpha=alpha n=n ]
#      p.d.f value is Not-a-Number @ m=dimuon_M=2940.83, m0=mean=3099.13, sigma=sigma2=49.458, alpha=alpha=2.04156, n=n=-0.389637
#      p.d.f value is Not-a-Number @ m=dimuon_M=2849.7, m0=mean=3099.13, sigma=sigma2=49.458, alpha=alpha=2.04156, n=n=-0.389637
#      p.d.f value is Not-a-Number @ m=dimuon_M=2834.18, m0=mean=3099.13, sigma=sigma2=49.458, alpha=alpha=2.04156, n=n=-0.389637
#      p.d.f value is Not-a-Number @ m=dimuon_M=2834.73, m0=mean=3099.13, sigma=sigma2=49.458, alpha=alpha=2.04156, n=n=-0.389637
#      p.d.f value is Not-a-Number @ m=dimuon_M=2914.06, m0=mean=3099.13, sigma=sigma2=49.458, alpha=alpha=2.04156, n=n=-0.389637
#      p.d.f value is Not-a-Number @ m=dimuon_M=2978.56, m0=mean=3099.13, sigma=sigma2=49.458, alpha=alpha=2.04156, n=n=-0.389637
#      p.d.f value is Not-a-Number @ m=dimuon_M=2819.06, m0=mean=3099.13, sigma=sigma2=49.458, alpha=alpha=2.04156, n=n=-0.389637
#      p.d.f value is Not-a-Number @ m=dimuon_M=2960.53, m0=mean=3099.13, sigma=sigma2=49.458, alpha=alpha=2.04156, n=n=-0.389637
#      p.d.f value is Not-a-Number @ m=dimuon_M=2984.98, m0=mean=3099.13, sigma=sigma2=49.458, alpha=alpha=2.04156, n=n=-0.389637
#      p.d.f value is Not-a-Number @ m=dimuon_M=2864.24, m0=mean=3099.13, sigma=sigma2=49.458, alpha=alpha=2.04156, n=n=-0.389637
#      p.d.f value is Not-a-Number @ m=dimuon_M=2974.75, m0=mean=3099.13, sigma=sigma2=49.458, alpha=alpha=2.04156, n=n=-0.389637
#      p.d.f value is Not-a-Number @ m=dimuon_M=2992.74, m0=mean=3099.13, sigma=sigma2=49.458, alpha=alpha=2.04156, n=n=-0.389637
#     ... (remaining 1620 messages suppressed)
# RooRealIntegral::cb_Int[dimuon_M][ Int cbd[Ana](dimuon_M) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(dimuon_M = 3132.94), !jacList=(), !facList=(), !func=cb=0.791619/122.583, !sumCat=()
#
#  MIGRAD FAILS TO FIND IMPROVEMENT
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=234609 FROM MIGRAD    STATUS=CONVERGED     679 CALLS         680 TOTAL
#                      EDM=0.000356032    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  alpha        8.94071e-01   1.26605e-01   2.64790e-03  -3.20469e-01
#    2  mean         3.10149e+03   2.18861e-01   2.35725e-03   3.71723e-01
#    3  n            2.66987e+00   7.04547e-01   2.20799e-03  -4.11348e-01
#    4  sig_frac     8.63503e-01   1.40848e-02   3.04604e-03   7.38501e-01
#    5  sigma1       3.91860e+01   3.70427e-01   1.07134e-02   1.91693e-01
#    6  sigma2       7.60105e+01   2.41923e+00   9.82721e-03  -1.50757e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  6    ERR DEF=0.5
#   1.604e-02 -5.292e-03 -8.360e-02 -1.607e-03  3.622e-02 -2.323e-01
#  -5.292e-03  4.790e-02  2.826e-02  3.752e-04 -8.533e-03  1.668e-02
#  -8.360e-02  2.826e-02  4.965e-01  7.421e-03 -1.608e-01  1.116e+00
#  -1.607e-03  3.752e-04  7.421e-03  1.985e-04 -4.548e-03  2.954e-02
#   3.622e-02 -8.533e-03 -1.608e-01 -4.548e-03  1.374e-01 -6.306e-01
#  -2.323e-01  1.668e-02  1.116e+00  2.954e-02 -6.306e-01  5.860e+00
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6
#         1  0.98578   1.000 -0.191 -0.937 -0.901  0.772 -0.758
#         2  0.26265  -0.191  1.000  0.183  0.122 -0.105  0.031
#         3  0.96589  -0.937  0.183  1.000  0.748 -0.615  0.654
#         4  0.97509  -0.901  0.122  0.748  1.000 -0.871  0.866
#         5  0.87858   0.772 -0.105 -0.615 -0.871  1.000 -0.703
#         6  0.88517  -0.758  0.031  0.654  0.866 -0.703  1.000
#  **********
#  **   16 **SET ERR         0.5
#  **********
#  **********
#  **   17 **SET PRINT           1
#  **********
#  **********
#  **   18 **HESSE        3000
#  **********
#  COVARIANCE MATRIX CALCULATED SUCCESSFULLY
#  FCN=234609 FROM HESSE     STATUS=OK             40 CALLS         720 TOTAL
#                      EDM=0.000338139    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                INTERNAL      INTERNAL
#   NO.   NAME      VALUE            ERROR       STEP SIZE       VALUE
#    1  alpha        8.94071e-01   1.23227e-01   5.29580e-04  -9.96513e-01
#    2  mean         3.10149e+03   2.18913e-01   4.71451e-04   4.97766e-02
#    3  n            2.66987e+00   6.99957e-01   8.83194e-05  -1.02345e+00
#    4  sig_frac     8.63503e-01   1.33912e-02   6.09208e-04   8.13951e-01
#    5  sigma1       3.91860e+01   3.48799e-01   4.28535e-04   1.86456e+00
#    6  sigma2       7.60105e+01   2.35187e+00   3.93088e-04   4.50639e-01
#                                ERR DEF= 0.5
#  EXTERNAL ERROR MATRIX.    NDIM=  25    NPAR=  6    ERR DEF=0.5
#   1.520e-02 -5.134e-03 -8.066e-02 -1.467e-03  3.191e-02 -2.141e-01
#  -5.134e-03  4.792e-02  2.799e-02  3.390e-04 -7.412e-03  1.141e-02
#  -8.066e-02  2.799e-02  4.900e-01  6.804e-03 -1.413e-01  1.036e+00
#  -1.467e-03  3.390e-04  6.804e-03  1.794e-04 -3.986e-03  2.704e-02
#   3.191e-02 -7.412e-03 -1.413e-01 -3.986e-03  1.218e-01 -5.546e-01
#  -2.141e-01  1.141e-02  1.036e+00  2.704e-02 -5.546e-01  5.538e+00
#  PARAMETER  CORRELATION COEFFICIENTS
#        NO.  GLOBAL      1      2      3      4      5      6
#         1  0.98498   1.000 -0.190 -0.935 -0.888  0.742 -0.738
#         2  0.26349  -0.190  1.000  0.183  0.116 -0.097  0.022
#         3  0.96541  -0.935  0.183  1.000  0.726 -0.578  0.629
#         4  0.97241  -0.888  0.116  0.726  1.000 -0.853  0.858
#         5  0.86174   0.742 -0.097 -0.578 -0.853  1.000 -0.675
#         6  0.87801  -0.738  0.022  0.629  0.858 -0.675  1.000
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %% [markdown]
# Facemos o plot dos resultados para comprobar visualmente

# %%
frame = mass.frame()

roo_data.plotOn(frame)
signal.plotOn(frame)   

c = ROOT.TCanvas()
frame.SetTitle("")
frame.Draw()
title_text = ROOT.TLatex()
title_text.SetNDC()              # Usa coordenadas da pantalla (0 a 1) no canto das dos eixes
title_text.SetTextSize(0.045)    # Tamaño do texto
title_text.SetTextFont(62)       # Tipo de letra (62 adoita ser negrita en ROOT)
title_text.SetTextAlign(21)      # Aliñación: 2 (centro horizontal), 1 (abaixo vertical)

# Debuxamos o título na posición X=0.5 (centro) e Y=0.92 (arriba do todo)
title_text.DrawLatex(0.5, 0.92, "Axustes VM pO (MC)")
c.Draw()
